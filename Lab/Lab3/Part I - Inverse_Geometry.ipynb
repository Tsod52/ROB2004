# %% [markdown]
# # Inverse Geometry
#
# ## Instructions
# Answer all the questions below and submit a pdf with detailed answers to these questions, including the plots through Brightspace. You will also need to submit the Jupyter notebook(s) with the code used to answer the questions.
#
# **This laboratory (part I & II) can be completed over the next two lab sessions**
#
# ## Introduction
#
# As we saw in the last laboratories, it is not obvious to get the tip of the finger to follow a given movement, such as a circle. Last laboratory you computed the forward kinematics of the robot, which provides the position of the fingertip given the measured joint angles. In this laboratory, we will use this function to do the inverse: find joint positions that will realize a desired fingertip position.
#
# ## Robot model
# As a reminder, below is the kinematic model of the robot <img src="./3d_robot_model.png" width="500">
#
# ## Inverse Geometry / Inverse Kinematics Problem
#
# The inverse geometry problem is the following: given a desired fingertip position (given in the S frame) $p_{SF} = (x_{des},y_{des}, z_{des})$, can we find joint angles $\theta_0$, $\theta_1$ and $\theta_2$ that would attain this position (if they exist)? Denoting $p_{FK}(\theta)$ the (forward kinematics) function that returns the fingertip position, given a joint angle configuration, our problem is to find the vector of joint angles $\theta$ that solves the equation
# $$p_{FK}(\theta) = \begin{pmatrix} x_{des}\\ y_{des}\\ z_{des} \end{pmatrix}$$
#
# **Key Take Away - Inverse Geometry determines the joint positions of the robot using the given tip location**
#
# ## Recasting the problem as an optimization problem
#
# We saw in class that solutions to this equation are also solutions to the following optimization problem
# $$\min_{\theta} \left(p_{FK}(\theta) - \begin{pmatrix} x_{des}\\ y_{des}\\ z_{des} \end{pmatrix}\right)^2$$
# when we attain 0 as a minimum. When 0 is not attained, we get the "closest" possible solution, i.e. the attainable fingertip position that is closest to the desired one (when the desired one is not attainable).

# %%
# we import useful libraries
from time import sleep
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import scipy
from NYUFinger.sim import NYUFingerSimulator

# Set this to true and restart the kernel to use the real robot
use_real_robot = False

if use_real_robot:
    from NYUFinger.real import NYUFingerHardware
    robot = NYUFingerHardware()
else:
    robot = NYUFingerSimulator()

l0 = 0.3
l1 = 0.16
l2 = 0.16
l3 = 0.014
# Out:
# libdecor-gtk-WARNING: Failed to initialize GTK
# Failed to load plugin 'libdecor-gtk.so': failed to init
# /home/alberttsododo/.conda/envs/rob2004/lib/python3.13/site-packages/glfw/__init__.py:917: GLFWError: (65548) b'Wayland: The platform does not provide the window position'
#   warnings.warn(message, GLFWError)

# %% [markdown]
# **Note:** Rest the robot's sensors if you're using the real robot. Like what you did during previous weeks, put the robot into the zero position and run the following cell:

# %%
if use_real_robot:
    robot.reset_sensors()

# %% [markdown]
# ### Ratations and Translation Functions

# %%
def translate(vector):
    # we allocate a 4x4 array (as identity since this corresponds to no motion)
    transform = np.eye(4)
    # here you can fill the rest of the transform
    ##WRITE CODE HERE
    transform[0][3] = vector[0]
    transform[1][3] = vector[1]
    transform[2][3] = vector[2]

    ### we return the object
    return transform

def rotateX(angle):
    # we allocate a 4x4 array (as identity since this corresponds to no motion)
    transform = np.eye(4)
    # here you can fill the rest of the transform
    ##WRITE CODE HERE
    transform[1][1] = np.cos(angle)
    transform[1][2] = -(np.sin(angle))
    transform[2][1] = np.sin(angle)
    transform[2][2] = np.cos(angle)

    ### we return the object
    return transform

def rotateY(angle):
    # we allocate a 4x4 array (as identity since this corresponds to no motion)
    transform = np.eye(4)
    # here you can fill the rest of the transform
    ##WRITE CODE HERE
    transform[0][0] = np.cos(angle)
    transform[0][2] = (np.sin(angle))
    transform[2][0] = -np.sin(angle)
    transform[2][2] = np.cos(angle)
    
    ### we return the object
    return transform

def rotateZ(angle):
    # we allocate a 4x4 array (as identity since this corresponds to no motion)
    transform = np.eye(4)
    # here you can fill the rest of the transform
    ##WRITE CODE HERE
    transform[0][0] = np.cos(angle)
    transform[0][1] = -(np.sin(angle))
    transform[1][0] = np.sin(angle)
    transform[1][1] = np.cos(angle)
    
    ### we return the object
    return transform

# %% [markdown]
# ### Forward Kinematics Function

# %%
### COPY PASTE YOUR FORWARD KINEMATICS FUNCTION HERE FROM LAB 2 (and other helper functions)
def forward_kinematics(theta):
    # assume theta is a vector, theta[0] = theta0, theta[1] = theta1, etc.
    # we define the lengths of the robot
    l0 = 0.3
    l1 = 0.16
    l2 = 0.16
    l3 = 0.014
    
    ###WRITE YOUR CODE HERE
    t_SH1 = translate([l0,0,0]) @ rotateX(theta[0]) # translation in x by l0 and rotation in x by theta[0]

    t_H1H2 = translate([0,0,l3]) @ rotateZ(theta[1])#translation in z by l3 and rotation in z by theta[1]

    t_H2K = translate([0,-l1,0]) @ rotateZ(theta[2]) #translation in y by l1 and rotation in z by theta[2]

    t_KF = translate([0,-l2,0]) #translation in y by l2
    
    t_SF = t_SH1 @ t_H1H2 @ t_H2K @ t_KF
    
    ### we return the object
    return t_SF

# %% [markdown]
# ## Question 1: Inverse Geometry
#
# 1. Write a function ``fingertip_position_error`` (cf. function sekeleton below) that takes as arguments ``joint_angles`` (as a vector) and ``desired_fingertip_position`` and return the squared distance between the fingertip position realized by joint_angles and the desired one, i.e. it returns $$\left(p_{FK}(\mathrm{joint\_angles}) - \mathrm{desired\_fingertip\_position}\right)^2$$
#
# 2. Write a function ``inverse_geometry`` that takes as an argument the desired fingertip position and returns a vector of joint angles that best realize this position (i.e. for which the fingertip position is as close as possible to the desired one). Use the ``minimize`` function from SciPy to do it - as seen in class.
#
# 3. Test that both of your functions work as expected. Explain what test you conducted and why it gives you confidence that the function works as expected.

# %%
from NYUFinger import real

def fingertip_position_error(joint_angles, desired_fingertip_position):
    """
    fingertip_position_error function
    input joint_angles (as a 3D vector) and desired_fingertip_position (as a 3D vector)
    output the squared distance between the desired fingertip position and the one realized by joint_angles
    """
    realized_fingertip_position = forward_kinematics(joint_angles)[0:3,3]
    dist = realized_fingertip_position - desired_fingertip_position
    error = (dist[0]**2 + dist[1]**2 + dist[2]**2)
    return error

def inverse_geometry(desired_fingertip_position):
    """
    inverse geometry function
    input desired_fingertip_position (3D vector of desired position of the fingertip)
    output a vector of joint angles
    """
    # Initial guess for joint angles (use a better guess if possible)
    x0 = np.zeros(3)+0.3  
    # Minimize the fingertip position error
    res = scipy.optimize.minimize(fingertip_position_error,  x0, args =(desired_fingertip_position))
    
    return res.x


# Test for fingertip_position_error
test_joint_angles = np.array([0.0, 0.0, np.pi/2])  # Example joint angles
test_desired_position = np.array([l0+l2,-(l1),l3])  # Example desired position

# Compute the error
error = fingertip_position_error(test_joint_angles, test_desired_position)
print("Fingertip Position Error:", error)

print()
#Test the inverse geometry function
desired_fingertip_position = np.array([l0+l2, -(l1),l3])
Joint_anles= inverse_geometry(desired_fingertip_position)

print("Joint Angles:", Joint_anles)
# Out:
# Fingertip Position Error: 0.0
#
# Joint Angles: [ 2.12745974e-05 -4.26928072e-05  1.57080084e+00]

# %% [markdown]
# # Question 2: reaching controller
# The code below generates 3 target ball locations (and displays them). Their locations are in the variable ball_position (a list containing 3D vectors of x,y,z positions). The goal is to modify all the code below (our typical control loop with a PD controller) such that the robot moves from its current position to each ball successively. To achieve this follow the steps below:
#
# ## Part 1:
#
# 1. Write an interpolate function to generate a smooth joint trajectory from a given initial and final joint positions in the desired time.  **NOTE : Read the linear time parametrization section in the jupyter notebook part II. Implement the linear_interpolate_trajectory() using the equations mentioned there.**

# %%
def linear_interpolate_trajectory(position_init, position_goal, t_init, t_goal, t):
    desired_position = 0
    desired_velocity = 0
    
    # Total time of the trajectory
    T_total = t_goal - t_init

    s_t=(t-t_init)/T_total
    
    # we compute the desired position
    desired_position=position_init+s_t*(position_goal-position_init)

    # we compute the desired velocity
    desired_velocity=(position_goal-position_init)/T_total
    
    # we return the answer
    return desired_position, desired_velocity

# %% [markdown]
# ## Part 2:
# 2. Use the inverse geometry function to decide what the end joint angles should be for each ball (you can get them in the ball_positions array) and store them in another array called joint_positions_of_balls.
# 3. Now use the linear_interpolate_trajectory() function in the control loop to generate a smooth joint trajectory for the robot to move from its initial position to all the three balls, one after the other. The robot should reach each ball in T=3 seconds (i.e. go from initial configuration of the robot to ball 1 in 3 seconds, then move from ball 1 to ball 2 in 3 seconds and finally move from ball 2 to ball 3 in 3 seconds).
# 4. Use the plotting function below to plot the motion of the fingertip in space and the joint position/velocity trajectories. How well does it go through the targets? Can you provide an explanation for this result?
# 5. Answer question 2. with the real robot

# %%
### THE BALL POSITIONS ARE DEFINED HERE ###
# here we create a list of ball positions and display them if we are in simulation

ball_positions = [np.array([0.597,-0.056, 0.0]), np.array([0.521,0.12, 0.0]), np.array([0.3,-0.225, 0.0])]

# we compute the end joint angle positions for the balls
joint_positions_of_balls = [inverse_geometry(ball_positions[0]), inverse_geometry(ball_positions[1]), inverse_geometry(ball_positions[2])]

if not use_real_robot:
    for ball in ball_positions:
        robot.add_ball(ball)
        

# we simulate for 9 seconds (3 seconds per goal)
run_time = 9.
dt = 0.001
num_steps = int(run_time/dt)

# the PD gains
P = np.array([1.5, 1.5, 1.5])
D = np.array([0.01, 0.01, 0.01])

## we allocate a few vectors to collect data while we do the simulation
# we will store the sensor values (angular position and velocities)
measured_positions = np.zeros([num_steps,3])
measured_velocities = np.zeros_like(measured_positions)
# we will store the commands sent to the robot
desired_torques = np.zeros_like(measured_positions)
# we will store the desired joint trajectories that the PD controller follows
desired_positions = np.zeros_like(measured_positions)
desired_velocities = np.zeros_like(measured_positions)
# we keep track of time
time = np.zeros([num_steps])
# we will store the end effector position (desired and measured)
measured_finger_position = np.zeros([num_steps,3])
desired_finger_position = np.zeros([num_steps,3])



# the time to reach a goal
time_to_goal = 3.0

# we use this to know which target we are currently aiming
ball_number = 0

# we measure the internal time for one target movement
t = 0.

## this is our main control loop ##
## we do the loop for num_steps ##
for i in range(num_steps):
    # get the current time and save it
    time[i] = dt * i
    
    # we read the position and velocities of the joints from the robot or simulation
    q, dq = robot.get_state()
    
    # we store these values for later use
    measured_positions[i, :] = q
    measured_velocities[i, :] = dq
    
    # save the current position of the fingertip using the FK function
    pose = forward_kinematics(q)
    measured_finger_position[i, :] = pose[0:3, 3]
    
    # Controller: Implement logic to reach all 3 targets
    # Check if it's time to switch to the next ball
    if t >= time_to_goal:
        if ball_number < len(joint_positions_of_balls) - 1:
            ball_number += 1
        t = 0  # Reset the internal timer for the next target
    
    # Interpolate the trajectory to the current target
    q_des = joint_positions_of_balls[ball_number]
    q_des, dq_des = linear_interpolate_trajectory(q, q_des, 0, time_to_goal, t)
    
    # Increment the internal timer
    t += dt
    
    # Save the desired positions/velocities for later plotting
    desired_positions[i, :] = q_des
    desired_velocities[i, :] = dq_des
    
    # PD Controller
    error = q_des - q  # Position error
    d_error = dq_des - dq  # Velocity error
    
    # Compute the desired torques using the PD controller
    joint_torques = P * error + D * d_error
    desired_torques[i, :] = joint_torques
    
    # Debugging: Print time and ball number
    print(f"Time: {time[i]:.3f}, Internal Timer t: {t:.3f}, Ball Number: {ball_number}")
    
    # Send the torques to the robot and perform one simulation step
    robot.send_joint_torque(joint_torques)
    sleep(robot.dt)
# Out:
# Time: 0.000, Internal Timer t: 0.001, Ball Number: 0
# Time: 0.001, Internal Timer t: 0.002, Ball Number: 0
# Time: 0.002, Internal Timer t: 0.003, Ball Number: 0
# Time: 0.003, Internal Timer t: 0.004, Ball Number: 0
# Time: 0.004, Internal Timer t: 0.005, Ball Number: 0
# Time: 0.005, Internal Timer t: 0.006, Ball Number: 0
# Time: 0.006, Internal Timer t: 0.007, Ball Number: 0
# Time: 0.007, Internal Timer t: 0.008, Ball Number: 0
# Time: 0.008, Internal Timer t: 0.009, Ball Number: 0
# Time: 0.009, Internal Timer t: 0.010, Ball Number: 0
# Time: 0.010, Internal Timer t: 0.011, Ball Number: 0
# Time: 0.011, Internal Timer t: 0.012, Ball Number: 0
# Time: 0.012, Internal Timer t: 0.013, Ball Number: 0
# Time: 0.013, Internal Timer t: 0.014, Ball Number: 0
# Time: 0.014, Internal Timer t: 0.015, Ball Number: 0
# Time: 0.015, Internal Timer t: 0.016, Ball Number: 0
# Time: 0.016, Internal Timer t: 0.017, Ball Number: 0
# Time: 0.017, Internal Timer t: 0.018, Ball Number: 0
# Time: 0.018, Internal Timer t: 0.019, Ball Number: 0
# Time: 0.019, Internal Timer t: 0.020, Ball Number: 0
# Time: 0.020, Internal Timer t: 0.021, Ball Number: 0
# Time: 0.021, Internal Timer t: 0.022, Ball Number: 0
# Time: 0.022, Internal Timer t: 0.023, Ball Number: 0
# Time: 0.023, Internal Timer t: 0.024, Ball Number: 0
# Time: 0.024, Internal Timer t: 0.025, Ball Number: 0
# Time: 0.025, Internal Timer t: 0.026, Ball Number: 0
# Time: 0.026, Internal Timer t: 0.027, Ball Number: 0
# Time: 0.027, Internal Timer t: 0.028, Ball Number: 0
# Time: 0.028, Internal Timer t: 0.029, Ball Number: 0
# Time: 0.029, Internal Timer t: 0.030, Ball Number: 0
# Time: 0.030, Internal Timer t: 0.031, Ball Number: 0
# Time: 0.031, Internal Timer t: 0.032, Ball Number: 0
# Time: 0.032, Internal Timer t: 0.033, Ball Number: 0
# Time: 0.033, Internal Timer t: 0.034, Ball Number: 0
# Time: 0.034, Internal Timer t: 0.035, Ball Number: 0
# Time: 0.035, Internal Timer t: 0.036, Ball Number: 0
# Time: 0.036, Internal Timer t: 0.037, Ball Number: 0
# Time: 0.037, Internal Timer t: 0.038, Ball Number: 0
# Time: 0.038, Internal Timer t: 0.039, Ball Number: 0
# Time: 0.039, Internal Timer t: 0.040, Ball Number: 0
# Time: 0.040, Internal Timer t: 0.041, Ball Number: 0
# Time: 0.041, Internal Timer t: 0.042, Ball Number: 0
# Time: 0.042, Internal Timer t: 0.043, Ball Number: 0
# Time: 0.043, Internal Timer t: 0.044, Ball Number: 0
# Time: 0.044, Internal Timer t: 0.045, Ball Number: 0
# Time: 0.045, Internal Timer t: 0.046, Ball Number: 0
# Time: 0.046, Internal Timer t: 0.047, Ball Number: 0
# Time: 0.047, Internal Timer t: 0.048, Ball Number: 0
# Time: 0.048, Internal Timer t: 0.049, Ball Number: 0
# Time: 0.049, Internal Timer t: 0.050, Ball Number: 0
# Time: 0.050, Internal Timer t: 0.051, Ball Number: 0
# Time: 0.051, Internal Timer t: 0.052, Ball Number: 0
# Time: 0.052, Internal Timer t: 0.053, Ball Number: 0
# Time: 0.053, Internal Timer t: 0.054, Ball Number: 0
# Time: 0.054, Internal Timer t: 0.055, Ball Number: 0
# Time: 0.055, Internal Timer t: 0.056, Ball Number: 0
# Time: 0.056, Internal Timer t: 0.057, Ball Number: 0
# Time: 0.057, Internal Timer t: 0.058, Ball Number: 0
# Time: 0.058, Internal Timer t: 0.059, Ball Number: 0
# Time: 0.059, Internal Timer t: 0.060, Ball Number: 0
# Time: 0.060, Internal Timer t: 0.061, Ball Number: 0
# Time: 0.061, Internal Timer t: 0.062, Ball Number: 0
# Time: 0.062, Internal Timer t: 0.063, Ball Number: 0
# Time: 0.063, Internal Timer t: 0.064, Ball Number: 0
# Time: 0.064, Internal Timer t: 0.065, Ball Number: 0
# Time: 0.065, Internal Timer t: 0.066, Ball Number: 0
# Time: 0.066, Internal Timer t: 0.067, Ball Number: 0
# Time: 0.067, Internal Timer t: 0.068, Ball Number: 0
# Time: 0.068, Internal Timer t: 0.069, Ball Number: 0
# Time: 0.069, Internal Timer t: 0.070, Ball Number: 0
# Time: 0.070, Internal Timer t: 0.071, Ball Number: 0
# Time: 0.071, Internal Timer t: 0.072, Ball Number: 0
# Time: 0.072, Internal Timer t: 0.073, Ball Number: 0
# Time: 0.073, Internal Timer t: 0.074, Ball Number: 0
# Time: 0.074, Internal Timer t: 0.075, Ball Number: 0
# Time: 0.075, Internal Timer t: 0.076, Ball Number: 0
# Time: 0.076, Internal Timer t: 0.077, Ball Number: 0
# Time: 0.077, Internal Timer t: 0.078, Ball Number: 0
# Time: 0.078, Internal Timer t: 0.079, Ball Number: 0
# Time: 0.079, Internal Timer t: 0.080, Ball Number: 0
# Time: 0.080, Internal Timer t: 0.081, Ball Number: 0
# Time: 0.081, Internal Timer t: 0.082, Ball Number: 0
# Time: 0.082, Internal Timer t: 0.083, Ball Number: 0
# Time: 0.083, Internal Timer t: 0.084, Ball Number: 0
# Time: 0.084, Internal Timer t: 0.085, Ball Number: 0
# Time: 0.085, Internal Timer t: 0.086, Ball Number: 0
# Time: 0.086, Internal Timer t: 0.087, Ball Number: 0
# Time: 0.087, Internal Timer t: 0.088, Ball Number: 0
# Time: 0.088, Internal Timer t: 0.089, Ball Number: 0
# Time: 0.089, Internal Timer t: 0.090, Ball Number: 0
# Time: 0.090, Internal Timer t: 0.091, Ball Number: 0
# Time: 0.091, Internal Timer t: 0.092, Ball Number: 0
# Time: 0.092, Internal Timer t: 0.093, Ball Number: 0
# Time: 0.093, Internal Timer t: 0.094, Ball Number: 0
# Time: 0.094, Internal Timer t: 0.095, Ball Number: 0
# Time: 0.095, Internal Timer t: 0.096, Ball Number: 0
# Time: 0.096, Internal Timer t: 0.097, Ball Number: 0
# Time: 0.097, Internal Timer t: 0.098, Ball Number: 0
# Time: 0.098, Internal Timer t: 0.099, Ball Number: 0
# Time: 0.099, Internal Timer t: 0.100, Ball Number: 0
# Time: 0.100, Internal Timer t: 0.101, Ball Number: 0
# Time: 0.101, Internal Timer t: 0.102, Ball Number: 0
# Time: 0.102, Internal Timer t: 0.103, Ball Number: 0
# Time: 0.103, Internal Timer t: 0.104, Ball Number: 0
# Time: 0.104, Internal Timer t: 0.105, Ball Number: 0
# Time: 0.105, Internal Timer t: 0.106, Ball Number: 0
# Time: 0.106, Internal Timer t: 0.107, Ball Number: 0
# Time: 0.107, Internal Timer t: 0.108, Ball Number: 0
# Time: 0.108, Internal Timer t: 0.109, Ball Number: 0
# Time: 0.109, Internal Timer t: 0.110, Ball Number: 0
# Time: 0.110, Internal Timer t: 0.111, Ball Number: 0
# Time: 0.111, Internal Timer t: 0.112, Ball Number: 0
# Time: 0.112, Internal Timer t: 0.113, Ball Number: 0
# Time: 0.113, Internal Timer t: 0.114, Ball Number: 0
# Time: 0.114, Internal Timer t: 0.115, Ball Number: 0
# Time: 0.115, Internal Timer t: 0.116, Ball Number: 0
# Time: 0.116, Internal Timer t: 0.117, Ball Number: 0
# Time: 0.117, Internal Timer t: 0.118, Ball Number: 0
# Time: 0.118, Internal Timer t: 0.119, Ball Number: 0
# Time: 0.119, Internal Timer t: 0.120, Ball Number: 0
# Time: 0.120, Internal Timer t: 0.121, Ball Number: 0
# Time: 0.121, Internal Timer t: 0.122, Ball Number: 0
# Time: 0.122, Internal Timer t: 0.123, Ball Number: 0
# Time: 0.123, Internal Timer t: 0.124, Ball Number: 0
# Time: 0.124, Internal Timer t: 0.125, Ball Number: 0
# Time: 0.125, Internal Timer t: 0.126, Ball Number: 0
# Time: 0.126, Internal Timer t: 0.127, Ball Number: 0
# Time: 0.127, Internal Timer t: 0.128, Ball Number: 0
# Time: 0.128, Internal Timer t: 0.129, Ball Number: 0
# Time: 0.129, Internal Timer t: 0.130, Ball Number: 0
# Time: 0.130, Internal Timer t: 0.131, Ball Number: 0
# Time: 0.131, Internal Timer t: 0.132, Ball Number: 0
# Time: 0.132, Internal Timer t: 0.133, Ball Number: 0
# Time: 0.133, Internal Timer t: 0.134, Ball Number: 0
# Time: 0.134, Internal Timer t: 0.135, Ball Number: 0
# Time: 0.135, Internal Timer t: 0.136, Ball Number: 0
# Time: 0.136, Internal Timer t: 0.137, Ball Number: 0
# Time: 0.137, Internal Timer t: 0.138, Ball Number: 0
# Time: 0.138, Internal Timer t: 0.139, Ball Number: 0
# Time: 0.139, Internal Timer t: 0.140, Ball Number: 0
# Time: 0.140, Internal Timer t: 0.141, Ball Number: 0
# Time: 0.141, Internal Timer t: 0.142, Ball Number: 0
# Time: 0.142, Internal Timer t: 0.143, Ball Number: 0
# Time: 0.143, Internal Timer t: 0.144, Ball Number: 0
# Time: 0.144, Internal Timer t: 0.145, Ball Number: 0
# Time: 0.145, Internal Timer t: 0.146, Ball Number: 0
# Time: 0.146, Internal Timer t: 0.147, Ball Number: 0
# Time: 0.147, Internal Timer t: 0.148, Ball Number: 0
# Time: 0.148, Internal Timer t: 0.149, Ball Number: 0
# Time: 0.149, Internal Timer t: 0.150, Ball Number: 0
# Time: 0.150, Internal Timer t: 0.151, Ball Number: 0
# Time: 0.151, Internal Timer t: 0.152, Ball Number: 0
# Time: 0.152, Internal Timer t: 0.153, Ball Number: 0
# Time: 0.153, Internal Timer t: 0.154, Ball Number: 0
# Time: 0.154, Internal Timer t: 0.155, Ball Number: 0
# Time: 0.155, Internal Timer t: 0.156, Ball Number: 0
# Time: 0.156, Internal Timer t: 0.157, Ball Number: 0
# Time: 0.157, Internal Timer t: 0.158, Ball Number: 0
# Time: 0.158, Internal Timer t: 0.159, Ball Number: 0
# Time: 0.159, Internal Timer t: 0.160, Ball Number: 0
# Time: 0.160, Internal Timer t: 0.161, Ball Number: 0
# Time: 0.161, Internal Timer t: 0.162, Ball Number: 0
# Time: 0.162, Internal Timer t: 0.163, Ball Number: 0
# Time: 0.163, Internal Timer t: 0.164, Ball Number: 0
# Time: 0.164, Internal Timer t: 0.165, Ball Number: 0
# Time: 0.165, Internal Timer t: 0.166, Ball Number: 0
# Time: 0.166, Internal Timer t: 0.167, Ball Number: 0
# Time: 0.167, Internal Timer t: 0.168, Ball Number: 0
# Time: 0.168, Internal Timer t: 0.169, Ball Number: 0
# Time: 0.169, Internal Timer t: 0.170, Ball Number: 0
# Time: 0.170, Internal Timer t: 0.171, Ball Number: 0
# Time: 0.171, Internal Timer t: 0.172, Ball Number: 0
# Time: 0.172, Internal Timer t: 0.173, Ball Number: 0
# Time: 0.173, Internal Timer t: 0.174, Ball Number: 0
# Time: 0.174, Internal Timer t: 0.175, Ball Number: 0
# Time: 0.175, Internal Timer t: 0.176, Ball Number: 0
# Time: 0.176, Internal Timer t: 0.177, Ball Number: 0
# Time: 0.177, Internal Timer t: 0.178, Ball Number: 0
# Time: 0.178, Internal Timer t: 0.179, Ball Number: 0
# Time: 0.179, Internal Timer t: 0.180, Ball Number: 0
# Time: 0.180, Internal Timer t: 0.181, Ball Number: 0
# Time: 0.181, Internal Timer t: 0.182, Ball Number: 0
# Time: 0.182, Internal Timer t: 0.183, Ball Number: 0
# Time: 0.183, Internal Timer t: 0.184, Ball Number: 0
# Time: 0.184, Internal Timer t: 0.185, Ball Number: 0
# Time: 0.185, Internal Timer t: 0.186, Ball Number: 0
# Time: 0.186, Internal Timer t: 0.187, Ball Number: 0
# Time: 0.187, Internal Timer t: 0.188, Ball Number: 0
# Time: 0.188, Internal Timer t: 0.189, Ball Number: 0
# Time: 0.189, Internal Timer t: 0.190, Ball Number: 0
# Time: 0.190, Internal Timer t: 0.191, Ball Number: 0
# Time: 0.191, Internal Timer t: 0.192, Ball Number: 0
# Time: 0.192, Internal Timer t: 0.193, Ball Number: 0
# Time: 0.193, Internal Timer t: 0.194, Ball Number: 0
# Time: 0.194, Internal Timer t: 0.195, Ball Number: 0
# Time: 0.195, Internal Timer t: 0.196, Ball Number: 0
# Time: 0.196, Internal Timer t: 0.197, Ball Number: 0
# Time: 0.197, Internal Timer t: 0.198, Ball Number: 0
# Time: 0.198, Internal Timer t: 0.199, Ball Number: 0
# Time: 0.199, Internal Timer t: 0.200, Ball Number: 0
# Time: 0.200, Internal Timer t: 0.201, Ball Number: 0
# Time: 0.201, Internal Timer t: 0.202, Ball Number: 0
# Time: 0.202, Internal Timer t: 0.203, Ball Number: 0
# Time: 0.203, Internal Timer t: 0.204, Ball Number: 0
# Time: 0.204, Internal Timer t: 0.205, Ball Number: 0
# Time: 0.205, Internal Timer t: 0.206, Ball Number: 0
# Time: 0.206, Internal Timer t: 0.207, Ball Number: 0
# Time: 0.207, Internal Timer t: 0.208, Ball Number: 0
# Time: 0.208, Internal Timer t: 0.209, Ball Number: 0
# Time: 0.209, Internal Timer t: 0.210, Ball Number: 0
# Time: 0.210, Internal Timer t: 0.211, Ball Number: 0
# Time: 0.211, Internal Timer t: 0.212, Ball Number: 0
# Time: 0.212, Internal Timer t: 0.213, Ball Number: 0
# Time: 0.213, Internal Timer t: 0.214, Ball Number: 0
# Time: 0.214, Internal Timer t: 0.215, Ball Number: 0
# Time: 0.215, Internal Timer t: 0.216, Ball Number: 0
# Time: 0.216, Internal Timer t: 0.217, Ball Number: 0
# Time: 0.217, Internal Timer t: 0.218, Ball Number: 0
# Time: 0.218, Internal Timer t: 0.219, Ball Number: 0
# Time: 0.219, Internal Timer t: 0.220, Ball Number: 0
# Time: 0.220, Internal Timer t: 0.221, Ball Number: 0
# Time: 0.221, Internal Timer t: 0.222, Ball Number: 0
# Time: 0.222, Internal Timer t: 0.223, Ball Number: 0
# Time: 0.223, Internal Timer t: 0.224, Ball Number: 0
# Time: 0.224, Internal Timer t: 0.225, Ball Number: 0
# Time: 0.225, Internal Timer t: 0.226, Ball Number: 0
# Time: 0.226, Internal Timer t: 0.227, Ball Number: 0
# Time: 0.227, Internal Timer t: 0.228, Ball Number: 0
# Time: 0.228, Internal Timer t: 0.229, Ball Number: 0
# Time: 0.229, Internal Timer t: 0.230, Ball Number: 0
# Time: 0.230, Internal Timer t: 0.231, Ball Number: 0
# Time: 0.231, Internal Timer t: 0.232, Ball Number: 0
# Time: 0.232, Internal Timer t: 0.233, Ball Number: 0
# Time: 0.233, Internal Timer t: 0.234, Ball Number: 0
# Time: 0.234, Internal Timer t: 0.235, Ball Number: 0
# Time: 0.235, Internal Timer t: 0.236, Ball Number: 0
# Time: 0.236, Internal Timer t: 0.237, Ball Number: 0
# Time: 0.237, Internal Timer t: 0.238, Ball Number: 0
# Time: 0.238, Internal Timer t: 0.239, Ball Number: 0
# Time: 0.239, Internal Timer t: 0.240, Ball Number: 0
# Time: 0.240, Internal Timer t: 0.241, Ball Number: 0
# Time: 0.241, Internal Timer t: 0.242, Ball Number: 0
# Time: 0.242, Internal Timer t: 0.243, Ball Number: 0
# Time: 0.243, Internal Timer t: 0.244, Ball Number: 0
# Time: 0.244, Internal Timer t: 0.245, Ball Number: 0
# Time: 0.245, Internal Timer t: 0.246, Ball Number: 0
# Time: 0.246, Internal Timer t: 0.247, Ball Number: 0
# Time: 0.247, Internal Timer t: 0.248, Ball Number: 0
# Time: 0.248, Internal Timer t: 0.249, Ball Number: 0
# Time: 0.249, Internal Timer t: 0.250, Ball Number: 0
# Time: 0.250, Internal Timer t: 0.251, Ball Number: 0
# Time: 0.251, Internal Timer t: 0.252, Ball Number: 0
# Time: 0.252, Internal Timer t: 0.253, Ball Number: 0
# Time: 0.253, Internal Timer t: 0.254, Ball Number: 0
# Time: 0.254, Internal Timer t: 0.255, Ball Number: 0
# Time: 0.255, Internal Timer t: 0.256, Ball Number: 0
# Time: 0.256, Internal Timer t: 0.257, Ball Number: 0
# Time: 0.257, Internal Timer t: 0.258, Ball Number: 0
# Time: 0.258, Internal Timer t: 0.259, Ball Number: 0
# Time: 0.259, Internal Timer t: 0.260, Ball Number: 0
# Time: 0.260, Internal Timer t: 0.261, Ball Number: 0
# Time: 0.261, Internal Timer t: 0.262, Ball Number: 0
# Time: 0.262, Internal Timer t: 0.263, Ball Number: 0
# Time: 0.263, Internal Timer t: 0.264, Ball Number: 0
# Time: 0.264, Internal Timer t: 0.265, Ball Number: 0
# Time: 0.265, Internal Timer t: 0.266, Ball Number: 0
# Time: 0.266, Internal Timer t: 0.267, Ball Number: 0
# Time: 0.267, Internal Timer t: 0.268, Ball Number: 0
# Time: 0.268, Internal Timer t: 0.269, Ball Number: 0
# Time: 0.269, Internal Timer t: 0.270, Ball Number: 0
# Time: 0.270, Internal Timer t: 0.271, Ball Number: 0
# Time: 0.271, Internal Timer t: 0.272, Ball Number: 0
# Time: 0.272, Internal Timer t: 0.273, Ball Number: 0
# Time: 0.273, Internal Timer t: 0.274, Ball Number: 0
# Time: 0.274, Internal Timer t: 0.275, Ball Number: 0
# Time: 0.275, Internal Timer t: 0.276, Ball Number: 0
# Time: 0.276, Internal Timer t: 0.277, Ball Number: 0
# Time: 0.277, Internal Timer t: 0.278, Ball Number: 0
# Time: 0.278, Internal Timer t: 0.279, Ball Number: 0
# Time: 0.279, Internal Timer t: 0.280, Ball Number: 0
# Time: 0.280, Internal Timer t: 0.281, Ball Number: 0
# Time: 0.281, Internal Timer t: 0.282, Ball Number: 0
# Time: 0.282, Internal Timer t: 0.283, Ball Number: 0
# Time: 0.283, Internal Timer t: 0.284, Ball Number: 0
# Time: 0.284, Internal Timer t: 0.285, Ball Number: 0
# Time: 0.285, Internal Timer t: 0.286, Ball Number: 0
# Time: 0.286, Internal Timer t: 0.287, Ball Number: 0
# Time: 0.287, Internal Timer t: 0.288, Ball Number: 0
# Time: 0.288, Internal Timer t: 0.289, Ball Number: 0
# Time: 0.289, Internal Timer t: 0.290, Ball Number: 0
# Time: 0.290, Internal Timer t: 0.291, Ball Number: 0
# Time: 0.291, Internal Timer t: 0.292, Ball Number: 0
# Time: 0.292, Internal Timer t: 0.293, Ball Number: 0
# Time: 0.293, Internal Timer t: 0.294, Ball Number: 0
# Time: 0.294, Internal Timer t: 0.295, Ball Number: 0
# Time: 0.295, Internal Timer t: 0.296, Ball Number: 0
# Time: 0.296, Internal Timer t: 0.297, Ball Number: 0
# Time: 0.297, Internal Timer t: 0.298, Ball Number: 0
# Time: 0.298, Internal Timer t: 0.299, Ball Number: 0
# Time: 0.299, Internal Timer t: 0.300, Ball Number: 0
# Time: 0.300, Internal Timer t: 0.301, Ball Number: 0
# Time: 0.301, Internal Timer t: 0.302, Ball Number: 0
# Time: 0.302, Internal Timer t: 0.303, Ball Number: 0
# Time: 0.303, Internal Timer t: 0.304, Ball Number: 0
# Time: 0.304, Internal Timer t: 0.305, Ball Number: 0
# Time: 0.305, Internal Timer t: 0.306, Ball Number: 0
# Time: 0.306, Internal Timer t: 0.307, Ball Number: 0
# Time: 0.307, Internal Timer t: 0.308, Ball Number: 0
# Time: 0.308, Internal Timer t: 0.309, Ball Number: 0
# Time: 0.309, Internal Timer t: 0.310, Ball Number: 0
# Time: 0.310, Internal Timer t: 0.311, Ball Number: 0
# Time: 0.311, Internal Timer t: 0.312, Ball Number: 0
# Time: 0.312, Internal Timer t: 0.313, Ball Number: 0
# Time: 0.313, Internal Timer t: 0.314, Ball Number: 0
# Time: 0.314, Internal Timer t: 0.315, Ball Number: 0
# Time: 0.315, Internal Timer t: 0.316, Ball Number: 0
# Time: 0.316, Internal Timer t: 0.317, Ball Number: 0
# Time: 0.317, Internal Timer t: 0.318, Ball Number: 0
# Time: 0.318, Internal Timer t: 0.319, Ball Number: 0
# Time: 0.319, Internal Timer t: 0.320, Ball Number: 0
# Time: 0.320, Internal Timer t: 0.321, Ball Number: 0
# Time: 0.321, Internal Timer t: 0.322, Ball Number: 0
# Time: 0.322, Internal Timer t: 0.323, Ball Number: 0
# Time: 0.323, Internal Timer t: 0.324, Ball Number: 0
# Time: 0.324, Internal Timer t: 0.325, Ball Number: 0
# Time: 0.325, Internal Timer t: 0.326, Ball Number: 0
# Time: 0.326, Internal Timer t: 0.327, Ball Number: 0
# Time: 0.327, Internal Timer t: 0.328, Ball Number: 0
# Time: 0.328, Internal Timer t: 0.329, Ball Number: 0
# Time: 0.329, Internal Timer t: 0.330, Ball Number: 0
# Time: 0.330, Internal Timer t: 0.331, Ball Number: 0
# Time: 0.331, Internal Timer t: 0.332, Ball Number: 0
# Time: 0.332, Internal Timer t: 0.333, Ball Number: 0
# Time: 0.333, Internal Timer t: 0.334, Ball Number: 0
# Time: 0.334, Internal Timer t: 0.335, Ball Number: 0
# Time: 0.335, Internal Timer t: 0.336, Ball Number: 0
# Time: 0.336, Internal Timer t: 0.337, Ball Number: 0
# Time: 0.337, Internal Timer t: 0.338, Ball Number: 0
# Time: 0.338, Internal Timer t: 0.339, Ball Number: 0
# Time: 0.339, Internal Timer t: 0.340, Ball Number: 0
# Time: 0.340, Internal Timer t: 0.341, Ball Number: 0
# Time: 0.341, Internal Timer t: 0.342, Ball Number: 0
# Time: 0.342, Internal Timer t: 0.343, Ball Number: 0
# Time: 0.343, Internal Timer t: 0.344, Ball Number: 0
# Time: 0.344, Internal Timer t: 0.345, Ball Number: 0
# Time: 0.345, Internal Timer t: 0.346, Ball Number: 0
# Time: 0.346, Internal Timer t: 0.347, Ball Number: 0
# Time: 0.347, Internal Timer t: 0.348, Ball Number: 0
# Time: 0.348, Internal Timer t: 0.349, Ball Number: 0
# Time: 0.349, Internal Timer t: 0.350, Ball Number: 0
# Time: 0.350, Internal Timer t: 0.351, Ball Number: 0
# Time: 0.351, Internal Timer t: 0.352, Ball Number: 0
# Time: 0.352, Internal Timer t: 0.353, Ball Number: 0
# Time: 0.353, Internal Timer t: 0.354, Ball Number: 0
# Time: 0.354, Internal Timer t: 0.355, Ball Number: 0
# Time: 0.355, Internal Timer t: 0.356, Ball Number: 0
# Time: 0.356, Internal Timer t: 0.357, Ball Number: 0
# Time: 0.357, Internal Timer t: 0.358, Ball Number: 0
# Time: 0.358, Internal Timer t: 0.359, Ball Number: 0
# Time: 0.359, Internal Timer t: 0.360, Ball Number: 0
# Time: 0.360, Internal Timer t: 0.361, Ball Number: 0
# Time: 0.361, Internal Timer t: 0.362, Ball Number: 0
# Time: 0.362, Internal Timer t: 0.363, Ball Number: 0
# Time: 0.363, Internal Timer t: 0.364, Ball Number: 0
# Time: 0.364, Internal Timer t: 0.365, Ball Number: 0
# Time: 0.365, Internal Timer t: 0.366, Ball Number: 0
# Time: 0.366, Internal Timer t: 0.367, Ball Number: 0
# Time: 0.367, Internal Timer t: 0.368, Ball Number: 0
# Time: 0.368, Internal Timer t: 0.369, Ball Number: 0
# Time: 0.369, Internal Timer t: 0.370, Ball Number: 0
# Time: 0.370, Internal Timer t: 0.371, Ball Number: 0
# Time: 0.371, Internal Timer t: 0.372, Ball Number: 0
# Time: 0.372, Internal Timer t: 0.373, Ball Number: 0
# Time: 0.373, Internal Timer t: 0.374, Ball Number: 0
# Time: 0.374, Internal Timer t: 0.375, Ball Number: 0
# Time: 0.375, Internal Timer t: 0.376, Ball Number: 0
# Time: 0.376, Internal Timer t: 0.377, Ball Number: 0
# Time: 0.377, Internal Timer t: 0.378, Ball Number: 0
# Time: 0.378, Internal Timer t: 0.379, Ball Number: 0
# Time: 0.379, Internal Timer t: 0.380, Ball Number: 0
# Time: 0.380, Internal Timer t: 0.381, Ball Number: 0
# Time: 0.381, Internal Timer t: 0.382, Ball Number: 0
# Time: 0.382, Internal Timer t: 0.383, Ball Number: 0
# Time: 0.383, Internal Timer t: 0.384, Ball Number: 0
# Time: 0.384, Internal Timer t: 0.385, Ball Number: 0
# Time: 0.385, Internal Timer t: 0.386, Ball Number: 0
# Time: 0.386, Internal Timer t: 0.387, Ball Number: 0
# Time: 0.387, Internal Timer t: 0.388, Ball Number: 0
# Time: 0.388, Internal Timer t: 0.389, Ball Number: 0
# Time: 0.389, Internal Timer t: 0.390, Ball Number: 0
# Time: 0.390, Internal Timer t: 0.391, Ball Number: 0
# Time: 0.391, Internal Timer t: 0.392, Ball Number: 0
# Time: 0.392, Internal Timer t: 0.393, Ball Number: 0
# Time: 0.393, Internal Timer t: 0.394, Ball Number: 0
# Time: 0.394, Internal Timer t: 0.395, Ball Number: 0
# Time: 0.395, Internal Timer t: 0.396, Ball Number: 0
# Time: 0.396, Internal Timer t: 0.397, Ball Number: 0
# Time: 0.397, Internal Timer t: 0.398, Ball Number: 0
# Time: 0.398, Internal Timer t: 0.399, Ball Number: 0
# Time: 0.399, Internal Timer t: 0.400, Ball Number: 0
# Time: 0.400, Internal Timer t: 0.401, Ball Number: 0
# Time: 0.401, Internal Timer t: 0.402, Ball Number: 0
# Time: 0.402, Internal Timer t: 0.403, Ball Number: 0
# Time: 0.403, Internal Timer t: 0.404, Ball Number: 0
# Time: 0.404, Internal Timer t: 0.405, Ball Number: 0
# Time: 0.405, Internal Timer t: 0.406, Ball Number: 0
# Time: 0.406, Internal Timer t: 0.407, Ball Number: 0
# Time: 0.407, Internal Timer t: 0.408, Ball Number: 0
# Time: 0.408, Internal Timer t: 0.409, Ball Number: 0
# Time: 0.409, Internal Timer t: 0.410, Ball Number: 0
# Time: 0.410, Internal Timer t: 0.411, Ball Number: 0
# Time: 0.411, Internal Timer t: 0.412, Ball Number: 0
# Time: 0.412, Internal Timer t: 0.413, Ball Number: 0
# Time: 0.413, Internal Timer t: 0.414, Ball Number: 0
# Time: 0.414, Internal Timer t: 0.415, Ball Number: 0
# Time: 0.415, Internal Timer t: 0.416, Ball Number: 0
# Time: 0.416, Internal Timer t: 0.417, Ball Number: 0
# Time: 0.417, Internal Timer t: 0.418, Ball Number: 0
# Time: 0.418, Internal Timer t: 0.419, Ball Number: 0
# Time: 0.419, Internal Timer t: 0.420, Ball Number: 0
# Time: 0.420, Internal Timer t: 0.421, Ball Number: 0
# Time: 0.421, Internal Timer t: 0.422, Ball Number: 0
# Time: 0.422, Internal Timer t: 0.423, Ball Number: 0
# Time: 0.423, Internal Timer t: 0.424, Ball Number: 0
# Time: 0.424, Internal Timer t: 0.425, Ball Number: 0
# Time: 0.425, Internal Timer t: 0.426, Ball Number: 0
# Time: 0.426, Internal Timer t: 0.427, Ball Number: 0
# Time: 0.427, Internal Timer t: 0.428, Ball Number: 0
# Time: 0.428, Internal Timer t: 0.429, Ball Number: 0
# Time: 0.429, Internal Timer t: 0.430, Ball Number: 0
# Time: 0.430, Internal Timer t: 0.431, Ball Number: 0
# Time: 0.431, Internal Timer t: 0.432, Ball Number: 0
# Time: 0.432, Internal Timer t: 0.433, Ball Number: 0
# Time: 0.433, Internal Timer t: 0.434, Ball Number: 0
# Time: 0.434, Internal Timer t: 0.435, Ball Number: 0
# Time: 0.435, Internal Timer t: 0.436, Ball Number: 0
# Time: 0.436, Internal Timer t: 0.437, Ball Number: 0
# Time: 0.437, Internal Timer t: 0.438, Ball Number: 0
# Time: 0.438, Internal Timer t: 0.439, Ball Number: 0
# Time: 0.439, Internal Timer t: 0.440, Ball Number: 0
# Time: 0.440, Internal Timer t: 0.441, Ball Number: 0
# Time: 0.441, Internal Timer t: 0.442, Ball Number: 0
# Time: 0.442, Internal Timer t: 0.443, Ball Number: 0
# Time: 0.443, Internal Timer t: 0.444, Ball Number: 0
# Time: 0.444, Internal Timer t: 0.445, Ball Number: 0
# Time: 0.445, Internal Timer t: 0.446, Ball Number: 0
# Time: 0.446, Internal Timer t: 0.447, Ball Number: 0
# Time: 0.447, Internal Timer t: 0.448, Ball Number: 0
# Time: 0.448, Internal Timer t: 0.449, Ball Number: 0
# Time: 0.449, Internal Timer t: 0.450, Ball Number: 0
# Time: 0.450, Internal Timer t: 0.451, Ball Number: 0
# Time: 0.451, Internal Timer t: 0.452, Ball Number: 0
# Time: 0.452, Internal Timer t: 0.453, Ball Number: 0
# Time: 0.453, Internal Timer t: 0.454, Ball Number: 0
# Time: 0.454, Internal Timer t: 0.455, Ball Number: 0
# Time: 0.455, Internal Timer t: 0.456, Ball Number: 0
# Time: 0.456, Internal Timer t: 0.457, Ball Number: 0
# Time: 0.457, Internal Timer t: 0.458, Ball Number: 0
# Time: 0.458, Internal Timer t: 0.459, Ball Number: 0
# Time: 0.459, Internal Timer t: 0.460, Ball Number: 0
# Time: 0.460, Internal Timer t: 0.461, Ball Number: 0
# Time: 0.461, Internal Timer t: 0.462, Ball Number: 0
# Time: 0.462, Internal Timer t: 0.463, Ball Number: 0
# Time: 0.463, Internal Timer t: 0.464, Ball Number: 0
# Time: 0.464, Internal Timer t: 0.465, Ball Number: 0
# Time: 0.465, Internal Timer t: 0.466, Ball Number: 0
# Time: 0.466, Internal Timer t: 0.467, Ball Number: 0
# Time: 0.467, Internal Timer t: 0.468, Ball Number: 0
# Time: 0.468, Internal Timer t: 0.469, Ball Number: 0
# Time: 0.469, Internal Timer t: 0.470, Ball Number: 0
# Time: 0.470, Internal Timer t: 0.471, Ball Number: 0
# Time: 0.471, Internal Timer t: 0.472, Ball Number: 0
# Time: 0.472, Internal Timer t: 0.473, Ball Number: 0
# Time: 0.473, Internal Timer t: 0.474, Ball Number: 0
# Time: 0.474, Internal Timer t: 0.475, Ball Number: 0
# Time: 0.475, Internal Timer t: 0.476, Ball Number: 0
# Time: 0.476, Internal Timer t: 0.477, Ball Number: 0
# Time: 0.477, Internal Timer t: 0.478, Ball Number: 0
# Time: 0.478, Internal Timer t: 0.479, Ball Number: 0
# Time: 0.479, Internal Timer t: 0.480, Ball Number: 0
# Time: 0.480, Internal Timer t: 0.481, Ball Number: 0
# Time: 0.481, Internal Timer t: 0.482, Ball Number: 0
# Time: 0.482, Internal Timer t: 0.483, Ball Number: 0
# Time: 0.483, Internal Timer t: 0.484, Ball Number: 0
# Time: 0.484, Internal Timer t: 0.485, Ball Number: 0
# Time: 0.485, Internal Timer t: 0.486, Ball Number: 0
# Time: 0.486, Internal Timer t: 0.487, Ball Number: 0
# Time: 0.487, Internal Timer t: 0.488, Ball Number: 0
# Time: 0.488, Internal Timer t: 0.489, Ball Number: 0
# Time: 0.489, Internal Timer t: 0.490, Ball Number: 0
# Time: 0.490, Internal Timer t: 0.491, Ball Number: 0
# Time: 0.491, Internal Timer t: 0.492, Ball Number: 0
# Time: 0.492, Internal Timer t: 0.493, Ball Number: 0
# Time: 0.493, Internal Timer t: 0.494, Ball Number: 0
# Time: 0.494, Internal Timer t: 0.495, Ball Number: 0
# Time: 0.495, Internal Timer t: 0.496, Ball Number: 0
# Time: 0.496, Internal Timer t: 0.497, Ball Number: 0
# Time: 0.497, Internal Timer t: 0.498, Ball Number: 0
# Time: 0.498, Internal Timer t: 0.499, Ball Number: 0
# Time: 0.499, Internal Timer t: 0.500, Ball Number: 0
# Time: 0.500, Internal Timer t: 0.501, Ball Number: 0
# Time: 0.501, Internal Timer t: 0.502, Ball Number: 0
# Time: 0.502, Internal Timer t: 0.503, Ball Number: 0
# Time: 0.503, Internal Timer t: 0.504, Ball Number: 0
# Time: 0.504, Internal Timer t: 0.505, Ball Number: 0
# Time: 0.505, Internal Timer t: 0.506, Ball Number: 0
# Time: 0.506, Internal Timer t: 0.507, Ball Number: 0
# Time: 0.507, Internal Timer t: 0.508, Ball Number: 0
# Time: 0.508, Internal Timer t: 0.509, Ball Number: 0
# Time: 0.509, Internal Timer t: 0.510, Ball Number: 0
# Time: 0.510, Internal Timer t: 0.511, Ball Number: 0
# Time: 0.511, Internal Timer t: 0.512, Ball Number: 0
# Time: 0.512, Internal Timer t: 0.513, Ball Number: 0
# Time: 0.513, Internal Timer t: 0.514, Ball Number: 0
# Time: 0.514, Internal Timer t: 0.515, Ball Number: 0
# Time: 0.515, Internal Timer t: 0.516, Ball Number: 0
# Time: 0.516, Internal Timer t: 0.517, Ball Number: 0
# Time: 0.517, Internal Timer t: 0.518, Ball Number: 0
# Time: 0.518, Internal Timer t: 0.519, Ball Number: 0
# Time: 0.519, Internal Timer t: 0.520, Ball Number: 0
# Time: 0.520, Internal Timer t: 0.521, Ball Number: 0
# Time: 0.521, Internal Timer t: 0.522, Ball Number: 0
# Time: 0.522, Internal Timer t: 0.523, Ball Number: 0
# Time: 0.523, Internal Timer t: 0.524, Ball Number: 0
# Time: 0.524, Internal Timer t: 0.525, Ball Number: 0
# Time: 0.525, Internal Timer t: 0.526, Ball Number: 0
# Time: 0.526, Internal Timer t: 0.527, Ball Number: 0
# Time: 0.527, Internal Timer t: 0.528, Ball Number: 0
# Time: 0.528, Internal Timer t: 0.529, Ball Number: 0
# Time: 0.529, Internal Timer t: 0.530, Ball Number: 0
# Time: 0.530, Internal Timer t: 0.531, Ball Number: 0
# Time: 0.531, Internal Timer t: 0.532, Ball Number: 0
# Time: 0.532, Internal Timer t: 0.533, Ball Number: 0
# Time: 0.533, Internal Timer t: 0.534, Ball Number: 0
# Time: 0.534, Internal Timer t: 0.535, Ball Number: 0
# Time: 0.535, Internal Timer t: 0.536, Ball Number: 0
# Time: 0.536, Internal Timer t: 0.537, Ball Number: 0
# Time: 0.537, Internal Timer t: 0.538, Ball Number: 0
# Time: 0.538, Internal Timer t: 0.539, Ball Number: 0
# Time: 0.539, Internal Timer t: 0.540, Ball Number: 0
# Time: 0.540, Internal Timer t: 0.541, Ball Number: 0
# Time: 0.541, Internal Timer t: 0.542, Ball Number: 0
# Time: 0.542, Internal Timer t: 0.543, Ball Number: 0
# Time: 0.543, Internal Timer t: 0.544, Ball Number: 0
# Time: 0.544, Internal Timer t: 0.545, Ball Number: 0
# Time: 0.545, Internal Timer t: 0.546, Ball Number: 0
# Time: 0.546, Internal Timer t: 0.547, Ball Number: 0
# Time: 0.547, Internal Timer t: 0.548, Ball Number: 0
# Time: 0.548, Internal Timer t: 0.549, Ball Number: 0
# Time: 0.549, Internal Timer t: 0.550, Ball Number: 0
# Time: 0.550, Internal Timer t: 0.551, Ball Number: 0
# Time: 0.551, Internal Timer t: 0.552, Ball Number: 0
# Time: 0.552, Internal Timer t: 0.553, Ball Number: 0
# Time: 0.553, Internal Timer t: 0.554, Ball Number: 0
# Time: 0.554, Internal Timer t: 0.555, Ball Number: 0
# Time: 0.555, Internal Timer t: 0.556, Ball Number: 0
# Time: 0.556, Internal Timer t: 0.557, Ball Number: 0
# Time: 0.557, Internal Timer t: 0.558, Ball Number: 0
# Time: 0.558, Internal Timer t: 0.559, Ball Number: 0
# Time: 0.559, Internal Timer t: 0.560, Ball Number: 0
# Time: 0.560, Internal Timer t: 0.561, Ball Number: 0
# Time: 0.561, Internal Timer t: 0.562, Ball Number: 0
# Time: 0.562, Internal Timer t: 0.563, Ball Number: 0
# Time: 0.563, Internal Timer t: 0.564, Ball Number: 0
# Time: 0.564, Internal Timer t: 0.565, Ball Number: 0
# Time: 0.565, Internal Timer t: 0.566, Ball Number: 0
# Time: 0.566, Internal Timer t: 0.567, Ball Number: 0
# Time: 0.567, Internal Timer t: 0.568, Ball Number: 0
# Time: 0.568, Internal Timer t: 0.569, Ball Number: 0
# Time: 0.569, Internal Timer t: 0.570, Ball Number: 0
# Time: 0.570, Internal Timer t: 0.571, Ball Number: 0
# Time: 0.571, Internal Timer t: 0.572, Ball Number: 0
# Time: 0.572, Internal Timer t: 0.573, Ball Number: 0
# Time: 0.573, Internal Timer t: 0.574, Ball Number: 0
# Time: 0.574, Internal Timer t: 0.575, Ball Number: 0
# Time: 0.575, Internal Timer t: 0.576, Ball Number: 0
# Time: 0.576, Internal Timer t: 0.577, Ball Number: 0
# Time: 0.577, Internal Timer t: 0.578, Ball Number: 0
# Time: 0.578, Internal Timer t: 0.579, Ball Number: 0
# Time: 0.579, Internal Timer t: 0.580, Ball Number: 0
# Time: 0.580, Internal Timer t: 0.581, Ball Number: 0
# Time: 0.581, Internal Timer t: 0.582, Ball Number: 0
# Time: 0.582, Internal Timer t: 0.583, Ball Number: 0
# Time: 0.583, Internal Timer t: 0.584, Ball Number: 0
# Time: 0.584, Internal Timer t: 0.585, Ball Number: 0
# Time: 0.585, Internal Timer t: 0.586, Ball Number: 0
# Time: 0.586, Internal Timer t: 0.587, Ball Number: 0
# Time: 0.587, Internal Timer t: 0.588, Ball Number: 0
# Time: 0.588, Internal Timer t: 0.589, Ball Number: 0
# Time: 0.589, Internal Timer t: 0.590, Ball Number: 0
# Time: 0.590, Internal Timer t: 0.591, Ball Number: 0
# Time: 0.591, Internal Timer t: 0.592, Ball Number: 0
# Time: 0.592, Internal Timer t: 0.593, Ball Number: 0
# Time: 0.593, Internal Timer t: 0.594, Ball Number: 0
# Time: 0.594, Internal Timer t: 0.595, Ball Number: 0
# Time: 0.595, Internal Timer t: 0.596, Ball Number: 0
# Time: 0.596, Internal Timer t: 0.597, Ball Number: 0
# Time: 0.597, Internal Timer t: 0.598, Ball Number: 0
# Time: 0.598, Internal Timer t: 0.599, Ball Number: 0
# Time: 0.599, Internal Timer t: 0.600, Ball Number: 0
# Time: 0.600, Internal Timer t: 0.601, Ball Number: 0
# Time: 0.601, Internal Timer t: 0.602, Ball Number: 0
# Time: 0.602, Internal Timer t: 0.603, Ball Number: 0
# Time: 0.603, Internal Timer t: 0.604, Ball Number: 0
# Time: 0.604, Internal Timer t: 0.605, Ball Number: 0
# Time: 0.605, Internal Timer t: 0.606, Ball Number: 0
# Time: 0.606, Internal Timer t: 0.607, Ball Number: 0
# Time: 0.607, Internal Timer t: 0.608, Ball Number: 0
# Time: 0.608, Internal Timer t: 0.609, Ball Number: 0
# Time: 0.609, Internal Timer t: 0.610, Ball Number: 0
# Time: 0.610, Internal Timer t: 0.611, Ball Number: 0
# Time: 0.611, Internal Timer t: 0.612, Ball Number: 0
# Time: 0.612, Internal Timer t: 0.613, Ball Number: 0
# Time: 0.613, Internal Timer t: 0.614, Ball Number: 0
# Time: 0.614, Internal Timer t: 0.615, Ball Number: 0
# Time: 0.615, Internal Timer t: 0.616, Ball Number: 0
# Time: 0.616, Internal Timer t: 0.617, Ball Number: 0
# Time: 0.617, Internal Timer t: 0.618, Ball Number: 0
# Time: 0.618, Internal Timer t: 0.619, Ball Number: 0
# Time: 0.619, Internal Timer t: 0.620, Ball Number: 0
# Time: 0.620, Internal Timer t: 0.621, Ball Number: 0
# Time: 0.621, Internal Timer t: 0.622, Ball Number: 0
# Time: 0.622, Internal Timer t: 0.623, Ball Number: 0
# Time: 0.623, Internal Timer t: 0.624, Ball Number: 0
# Time: 0.624, Internal Timer t: 0.625, Ball Number: 0
# Time: 0.625, Internal Timer t: 0.626, Ball Number: 0
# Time: 0.626, Internal Timer t: 0.627, Ball Number: 0
# Time: 0.627, Internal Timer t: 0.628, Ball Number: 0
# Time: 0.628, Internal Timer t: 0.629, Ball Number: 0
# Time: 0.629, Internal Timer t: 0.630, Ball Number: 0
# Time: 0.630, Internal Timer t: 0.631, Ball Number: 0
# Time: 0.631, Internal Timer t: 0.632, Ball Number: 0
# Time: 0.632, Internal Timer t: 0.633, Ball Number: 0
# Time: 0.633, Internal Timer t: 0.634, Ball Number: 0
# Time: 0.634, Internal Timer t: 0.635, Ball Number: 0
# Time: 0.635, Internal Timer t: 0.636, Ball Number: 0
# Time: 0.636, Internal Timer t: 0.637, Ball Number: 0
# Time: 0.637, Internal Timer t: 0.638, Ball Number: 0
# Time: 0.638, Internal Timer t: 0.639, Ball Number: 0
# Time: 0.639, Internal Timer t: 0.640, Ball Number: 0
# Time: 0.640, Internal Timer t: 0.641, Ball Number: 0
# Time: 0.641, Internal Timer t: 0.642, Ball Number: 0
# Time: 0.642, Internal Timer t: 0.643, Ball Number: 0
# Time: 0.643, Internal Timer t: 0.644, Ball Number: 0
# Time: 0.644, Internal Timer t: 0.645, Ball Number: 0
# Time: 0.645, Internal Timer t: 0.646, Ball Number: 0
# Time: 0.646, Internal Timer t: 0.647, Ball Number: 0
# Time: 0.647, Internal Timer t: 0.648, Ball Number: 0
# Time: 0.648, Internal Timer t: 0.649, Ball Number: 0
# Time: 0.649, Internal Timer t: 0.650, Ball Number: 0
# Time: 0.650, Internal Timer t: 0.651, Ball Number: 0
# Time: 0.651, Internal Timer t: 0.652, Ball Number: 0
# Time: 0.652, Internal Timer t: 0.653, Ball Number: 0
# Time: 0.653, Internal Timer t: 0.654, Ball Number: 0
# Time: 0.654, Internal Timer t: 0.655, Ball Number: 0
# Time: 0.655, Internal Timer t: 0.656, Ball Number: 0
# Time: 0.656, Internal Timer t: 0.657, Ball Number: 0
# Time: 0.657, Internal Timer t: 0.658, Ball Number: 0
# Time: 0.658, Internal Timer t: 0.659, Ball Number: 0
# Time: 0.659, Internal Timer t: 0.660, Ball Number: 0
# Time: 0.660, Internal Timer t: 0.661, Ball Number: 0
# Time: 0.661, Internal Timer t: 0.662, Ball Number: 0
# Time: 0.662, Internal Timer t: 0.663, Ball Number: 0
# Time: 0.663, Internal Timer t: 0.664, Ball Number: 0
# Time: 0.664, Internal Timer t: 0.665, Ball Number: 0
# Time: 0.665, Internal Timer t: 0.666, Ball Number: 0
# Time: 0.666, Internal Timer t: 0.667, Ball Number: 0
# Time: 0.667, Internal Timer t: 0.668, Ball Number: 0
# Time: 0.668, Internal Timer t: 0.669, Ball Number: 0
# Time: 0.669, Internal Timer t: 0.670, Ball Number: 0
# Time: 0.670, Internal Timer t: 0.671, Ball Number: 0
# Time: 0.671, Internal Timer t: 0.672, Ball Number: 0
# Time: 0.672, Internal Timer t: 0.673, Ball Number: 0
# Time: 0.673, Internal Timer t: 0.674, Ball Number: 0
# Time: 0.674, Internal Timer t: 0.675, Ball Number: 0
# Time: 0.675, Internal Timer t: 0.676, Ball Number: 0
# Time: 0.676, Internal Timer t: 0.677, Ball Number: 0
# Time: 0.677, Internal Timer t: 0.678, Ball Number: 0
# Time: 0.678, Internal Timer t: 0.679, Ball Number: 0
# Time: 0.679, Internal Timer t: 0.680, Ball Number: 0
# Time: 0.680, Internal Timer t: 0.681, Ball Number: 0
# Time: 0.681, Internal Timer t: 0.682, Ball Number: 0
# Time: 0.682, Internal Timer t: 0.683, Ball Number: 0
# Time: 0.683, Internal Timer t: 0.684, Ball Number: 0
# Time: 0.684, Internal Timer t: 0.685, Ball Number: 0
# Time: 0.685, Internal Timer t: 0.686, Ball Number: 0
# Time: 0.686, Internal Timer t: 0.687, Ball Number: 0
# Time: 0.687, Internal Timer t: 0.688, Ball Number: 0
# Time: 0.688, Internal Timer t: 0.689, Ball Number: 0
# Time: 0.689, Internal Timer t: 0.690, Ball Number: 0
# Time: 0.690, Internal Timer t: 0.691, Ball Number: 0
# Time: 0.691, Internal Timer t: 0.692, Ball Number: 0
# Time: 0.692, Internal Timer t: 0.693, Ball Number: 0
# Time: 0.693, Internal Timer t: 0.694, Ball Number: 0
# Time: 0.694, Internal Timer t: 0.695, Ball Number: 0
# Time: 0.695, Internal Timer t: 0.696, Ball Number: 0
# Time: 0.696, Internal Timer t: 0.697, Ball Number: 0
# Time: 0.697, Internal Timer t: 0.698, Ball Number: 0
# Time: 0.698, Internal Timer t: 0.699, Ball Number: 0
# Time: 0.699, Internal Timer t: 0.700, Ball Number: 0
# Time: 0.700, Internal Timer t: 0.701, Ball Number: 0
# Time: 0.701, Internal Timer t: 0.702, Ball Number: 0
# Time: 0.702, Internal Timer t: 0.703, Ball Number: 0
# Time: 0.703, Internal Timer t: 0.704, Ball Number: 0
# Time: 0.704, Internal Timer t: 0.705, Ball Number: 0
# Time: 0.705, Internal Timer t: 0.706, Ball Number: 0
# Time: 0.706, Internal Timer t: 0.707, Ball Number: 0
# Time: 0.707, Internal Timer t: 0.708, Ball Number: 0
# Time: 0.708, Internal Timer t: 0.709, Ball Number: 0
# Time: 0.709, Internal Timer t: 0.710, Ball Number: 0
# Time: 0.710, Internal Timer t: 0.711, Ball Number: 0
# Time: 0.711, Internal Timer t: 0.712, Ball Number: 0
# Time: 0.712, Internal Timer t: 0.713, Ball Number: 0
# Time: 0.713, Internal Timer t: 0.714, Ball Number: 0
# Time: 0.714, Internal Timer t: 0.715, Ball Number: 0
# Time: 0.715, Internal Timer t: 0.716, Ball Number: 0
# Time: 0.716, Internal Timer t: 0.717, Ball Number: 0
# Time: 0.717, Internal Timer t: 0.718, Ball Number: 0
# Time: 0.718, Internal Timer t: 0.719, Ball Number: 0
# Time: 0.719, Internal Timer t: 0.720, Ball Number: 0
# Time: 0.720, Internal Timer t: 0.721, Ball Number: 0
# Time: 0.721, Internal Timer t: 0.722, Ball Number: 0
# Time: 0.722, Internal Timer t: 0.723, Ball Number: 0
# Time: 0.723, Internal Timer t: 0.724, Ball Number: 0
# Time: 0.724, Internal Timer t: 0.725, Ball Number: 0
# Time: 0.725, Internal Timer t: 0.726, Ball Number: 0
# Time: 0.726, Internal Timer t: 0.727, Ball Number: 0
# Time: 0.727, Internal Timer t: 0.728, Ball Number: 0
# Time: 0.728, Internal Timer t: 0.729, Ball Number: 0
# Time: 0.729, Internal Timer t: 0.730, Ball Number: 0
# Time: 0.730, Internal Timer t: 0.731, Ball Number: 0
# Time: 0.731, Internal Timer t: 0.732, Ball Number: 0
# Time: 0.732, Internal Timer t: 0.733, Ball Number: 0
# Time: 0.733, Internal Timer t: 0.734, Ball Number: 0
# Time: 0.734, Internal Timer t: 0.735, Ball Number: 0
# Time: 0.735, Internal Timer t: 0.736, Ball Number: 0
# Time: 0.736, Internal Timer t: 0.737, Ball Number: 0
# Time: 0.737, Internal Timer t: 0.738, Ball Number: 0
# Time: 0.738, Internal Timer t: 0.739, Ball Number: 0
# Time: 0.739, Internal Timer t: 0.740, Ball Number: 0
# Time: 0.740, Internal Timer t: 0.741, Ball Number: 0
# Time: 0.741, Internal Timer t: 0.742, Ball Number: 0
# Time: 0.742, Internal Timer t: 0.743, Ball Number: 0
# Time: 0.743, Internal Timer t: 0.744, Ball Number: 0
# Time: 0.744, Internal Timer t: 0.745, Ball Number: 0
# Time: 0.745, Internal Timer t: 0.746, Ball Number: 0
# Time: 0.746, Internal Timer t: 0.747, Ball Number: 0
# Time: 0.747, Internal Timer t: 0.748, Ball Number: 0
# Time: 0.748, Internal Timer t: 0.749, Ball Number: 0
# Time: 0.749, Internal Timer t: 0.750, Ball Number: 0
# Time: 0.750, Internal Timer t: 0.751, Ball Number: 0
# Time: 0.751, Internal Timer t: 0.752, Ball Number: 0
# Time: 0.752, Internal Timer t: 0.753, Ball Number: 0
# Time: 0.753, Internal Timer t: 0.754, Ball Number: 0
# Time: 0.754, Internal Timer t: 0.755, Ball Number: 0
# Time: 0.755, Internal Timer t: 0.756, Ball Number: 0
# Time: 0.756, Internal Timer t: 0.757, Ball Number: 0
# Time: 0.757, Internal Timer t: 0.758, Ball Number: 0
# Time: 0.758, Internal Timer t: 0.759, Ball Number: 0
# Time: 0.759, Internal Timer t: 0.760, Ball Number: 0
# Time: 0.760, Internal Timer t: 0.761, Ball Number: 0
# Time: 0.761, Internal Timer t: 0.762, Ball Number: 0
# Time: 0.762, Internal Timer t: 0.763, Ball Number: 0
# Time: 0.763, Internal Timer t: 0.764, Ball Number: 0
# Time: 0.764, Internal Timer t: 0.765, Ball Number: 0
# Time: 0.765, Internal Timer t: 0.766, Ball Number: 0
# Time: 0.766, Internal Timer t: 0.767, Ball Number: 0
# Time: 0.767, Internal Timer t: 0.768, Ball Number: 0
# Time: 0.768, Internal Timer t: 0.769, Ball Number: 0
# Time: 0.769, Internal Timer t: 0.770, Ball Number: 0
# Time: 0.770, Internal Timer t: 0.771, Ball Number: 0
# Time: 0.771, Internal Timer t: 0.772, Ball Number: 0
# Time: 0.772, Internal Timer t: 0.773, Ball Number: 0
# Time: 0.773, Internal Timer t: 0.774, Ball Number: 0
# Time: 0.774, Internal Timer t: 0.775, Ball Number: 0
# Time: 0.775, Internal Timer t: 0.776, Ball Number: 0
# Time: 0.776, Internal Timer t: 0.777, Ball Number: 0
# Time: 0.777, Internal Timer t: 0.778, Ball Number: 0
# Time: 0.778, Internal Timer t: 0.779, Ball Number: 0
# Time: 0.779, Internal Timer t: 0.780, Ball Number: 0
# Time: 0.780, Internal Timer t: 0.781, Ball Number: 0
# Time: 0.781, Internal Timer t: 0.782, Ball Number: 0
# Time: 0.782, Internal Timer t: 0.783, Ball Number: 0
# Time: 0.783, Internal Timer t: 0.784, Ball Number: 0
# Time: 0.784, Internal Timer t: 0.785, Ball Number: 0
# Time: 0.785, Internal Timer t: 0.786, Ball Number: 0
# Time: 0.786, Internal Timer t: 0.787, Ball Number: 0
# Time: 0.787, Internal Timer t: 0.788, Ball Number: 0
# Time: 0.788, Internal Timer t: 0.789, Ball Number: 0
# Time: 0.789, Internal Timer t: 0.790, Ball Number: 0
# Time: 0.790, Internal Timer t: 0.791, Ball Number: 0
# Time: 0.791, Internal Timer t: 0.792, Ball Number: 0
# Time: 0.792, Internal Timer t: 0.793, Ball Number: 0
# Time: 0.793, Internal Timer t: 0.794, Ball Number: 0
# Time: 0.794, Internal Timer t: 0.795, Ball Number: 0
# Time: 0.795, Internal Timer t: 0.796, Ball Number: 0
# Time: 0.796, Internal Timer t: 0.797, Ball Number: 0
# Time: 0.797, Internal Timer t: 0.798, Ball Number: 0
# Time: 0.798, Internal Timer t: 0.799, Ball Number: 0
# Time: 0.799, Internal Timer t: 0.800, Ball Number: 0
# Time: 0.800, Internal Timer t: 0.801, Ball Number: 0
# Time: 0.801, Internal Timer t: 0.802, Ball Number: 0
# Time: 0.802, Internal Timer t: 0.803, Ball Number: 0
# Time: 0.803, Internal Timer t: 0.804, Ball Number: 0
# Time: 0.804, Internal Timer t: 0.805, Ball Number: 0
# Time: 0.805, Internal Timer t: 0.806, Ball Number: 0
# Time: 0.806, Internal Timer t: 0.807, Ball Number: 0
# Time: 0.807, Internal Timer t: 0.808, Ball Number: 0
# Time: 0.808, Internal Timer t: 0.809, Ball Number: 0
# Time: 0.809, Internal Timer t: 0.810, Ball Number: 0
# Time: 0.810, Internal Timer t: 0.811, Ball Number: 0
# Time: 0.811, Internal Timer t: 0.812, Ball Number: 0
# Time: 0.812, Internal Timer t: 0.813, Ball Number: 0
# Time: 0.813, Internal Timer t: 0.814, Ball Number: 0
# Time: 0.814, Internal Timer t: 0.815, Ball Number: 0
# Time: 0.815, Internal Timer t: 0.816, Ball Number: 0
# Time: 0.816, Internal Timer t: 0.817, Ball Number: 0
# Time: 0.817, Internal Timer t: 0.818, Ball Number: 0
# Time: 0.818, Internal Timer t: 0.819, Ball Number: 0
# Time: 0.819, Internal Timer t: 0.820, Ball Number: 0
# Time: 0.820, Internal Timer t: 0.821, Ball Number: 0
# Time: 0.821, Internal Timer t: 0.822, Ball Number: 0
# Time: 0.822, Internal Timer t: 0.823, Ball Number: 0
# Time: 0.823, Internal Timer t: 0.824, Ball Number: 0
# Time: 0.824, Internal Timer t: 0.825, Ball Number: 0
# Time: 0.825, Internal Timer t: 0.826, Ball Number: 0
# Time: 0.826, Internal Timer t: 0.827, Ball Number: 0
# Time: 0.827, Internal Timer t: 0.828, Ball Number: 0
# Time: 0.828, Internal Timer t: 0.829, Ball Number: 0
# Time: 0.829, Internal Timer t: 0.830, Ball Number: 0
# Time: 0.830, Internal Timer t: 0.831, Ball Number: 0
# Time: 0.831, Internal Timer t: 0.832, Ball Number: 0
# Time: 0.832, Internal Timer t: 0.833, Ball Number: 0
# Time: 0.833, Internal Timer t: 0.834, Ball Number: 0
# Time: 0.834, Internal Timer t: 0.835, Ball Number: 0
# Time: 0.835, Internal Timer t: 0.836, Ball Number: 0
# Time: 0.836, Internal Timer t: 0.837, Ball Number: 0
# Time: 0.837, Internal Timer t: 0.838, Ball Number: 0
# Time: 0.838, Internal Timer t: 0.839, Ball Number: 0
# Time: 0.839, Internal Timer t: 0.840, Ball Number: 0
# Time: 0.840, Internal Timer t: 0.841, Ball Number: 0
# Time: 0.841, Internal Timer t: 0.842, Ball Number: 0
# Time: 0.842, Internal Timer t: 0.843, Ball Number: 0
# Time: 0.843, Internal Timer t: 0.844, Ball Number: 0
# Time: 0.844, Internal Timer t: 0.845, Ball Number: 0
# Time: 0.845, Internal Timer t: 0.846, Ball Number: 0
# Time: 0.846, Internal Timer t: 0.847, Ball Number: 0
# Time: 0.847, Internal Timer t: 0.848, Ball Number: 0
# Time: 0.848, Internal Timer t: 0.849, Ball Number: 0
# Time: 0.849, Internal Timer t: 0.850, Ball Number: 0
# Time: 0.850, Internal Timer t: 0.851, Ball Number: 0
# Time: 0.851, Internal Timer t: 0.852, Ball Number: 0
# Time: 0.852, Internal Timer t: 0.853, Ball Number: 0
# Time: 0.853, Internal Timer t: 0.854, Ball Number: 0
# Time: 0.854, Internal Timer t: 0.855, Ball Number: 0
# Time: 0.855, Internal Timer t: 0.856, Ball Number: 0
# Time: 0.856, Internal Timer t: 0.857, Ball Number: 0
# Time: 0.857, Internal Timer t: 0.858, Ball Number: 0
# Time: 0.858, Internal Timer t: 0.859, Ball Number: 0
# Time: 0.859, Internal Timer t: 0.860, Ball Number: 0
# Time: 0.860, Internal Timer t: 0.861, Ball Number: 0
# Time: 0.861, Internal Timer t: 0.862, Ball Number: 0
# Time: 0.862, Internal Timer t: 0.863, Ball Number: 0
# Time: 0.863, Internal Timer t: 0.864, Ball Number: 0
# Time: 0.864, Internal Timer t: 0.865, Ball Number: 0
# Time: 0.865, Internal Timer t: 0.866, Ball Number: 0
# Time: 0.866, Internal Timer t: 0.867, Ball Number: 0
# Time: 0.867, Internal Timer t: 0.868, Ball Number: 0
# Time: 0.868, Internal Timer t: 0.869, Ball Number: 0
# Time: 0.869, Internal Timer t: 0.870, Ball Number: 0
# Time: 0.870, Internal Timer t: 0.871, Ball Number: 0
# Time: 0.871, Internal Timer t: 0.872, Ball Number: 0
# Time: 0.872, Internal Timer t: 0.873, Ball Number: 0
# Time: 0.873, Internal Timer t: 0.874, Ball Number: 0
# Time: 0.874, Internal Timer t: 0.875, Ball Number: 0
# Time: 0.875, Internal Timer t: 0.876, Ball Number: 0
# Time: 0.876, Internal Timer t: 0.877, Ball Number: 0
# Time: 0.877, Internal Timer t: 0.878, Ball Number: 0
# Time: 0.878, Internal Timer t: 0.879, Ball Number: 0
# Time: 0.879, Internal Timer t: 0.880, Ball Number: 0
# Time: 0.880, Internal Timer t: 0.881, Ball Number: 0
# Time: 0.881, Internal Timer t: 0.882, Ball Number: 0
# Time: 0.882, Internal Timer t: 0.883, Ball Number: 0
# Time: 0.883, Internal Timer t: 0.884, Ball Number: 0
# Time: 0.884, Internal Timer t: 0.885, Ball Number: 0
# Time: 0.885, Internal Timer t: 0.886, Ball Number: 0
# Time: 0.886, Internal Timer t: 0.887, Ball Number: 0
# Time: 0.887, Internal Timer t: 0.888, Ball Number: 0
# Time: 0.888, Internal Timer t: 0.889, Ball Number: 0
# Time: 0.889, Internal Timer t: 0.890, Ball Number: 0
# Time: 0.890, Internal Timer t: 0.891, Ball Number: 0
# Time: 0.891, Internal Timer t: 0.892, Ball Number: 0
# Time: 0.892, Internal Timer t: 0.893, Ball Number: 0
# Time: 0.893, Internal Timer t: 0.894, Ball Number: 0
# Time: 0.894, Internal Timer t: 0.895, Ball Number: 0
# Time: 0.895, Internal Timer t: 0.896, Ball Number: 0
# Time: 0.896, Internal Timer t: 0.897, Ball Number: 0
# Time: 0.897, Internal Timer t: 0.898, Ball Number: 0
# Time: 0.898, Internal Timer t: 0.899, Ball Number: 0
# Time: 0.899, Internal Timer t: 0.900, Ball Number: 0
# Time: 0.900, Internal Timer t: 0.901, Ball Number: 0
# Time: 0.901, Internal Timer t: 0.902, Ball Number: 0
# Time: 0.902, Internal Timer t: 0.903, Ball Number: 0
# Time: 0.903, Internal Timer t: 0.904, Ball Number: 0
# Time: 0.904, Internal Timer t: 0.905, Ball Number: 0
# ...
# Time: 8.699, Internal Timer t: 2.698, Ball Number: 2
# Time: 8.700, Internal Timer t: 2.699, Ball Number: 2
# Time: 8.701, Internal Timer t: 2.700, Ball Number: 2
# Time: 8.702, Internal Timer t: 2.701, Ball Number: 2
# Time: 8.703, Internal Timer t: 2.702, Ball Number: 2
# Time: 8.704, Internal Timer t: 2.703, Ball Number: 2
# Time: 8.705, Internal Timer t: 2.704, Ball Number: 2
# Time: 8.706, Internal Timer t: 2.705, Ball Number: 2
# Time: 8.707, Internal Timer t: 2.706, Ball Number: 2
# Time: 8.708, Internal Timer t: 2.707, Ball Number: 2
# Time: 8.709, Internal Timer t: 2.708, Ball Number: 2
# Time: 8.710, Internal Timer t: 2.709, Ball Number: 2
# Time: 8.711, Internal Timer t: 2.710, Ball Number: 2
# Time: 8.712, Internal Timer t: 2.711, Ball Number: 2
# Time: 8.713, Internal Timer t: 2.712, Ball Number: 2
# Time: 8.714, Internal Timer t: 2.713, Ball Number: 2
# Time: 8.715, Internal Timer t: 2.714, Ball Number: 2
# Time: 8.716, Internal Timer t: 2.715, Ball Number: 2
# Time: 8.717, Internal Timer t: 2.716, Ball Number: 2
# Time: 8.718, Internal Timer t: 2.717, Ball Number: 2
# Time: 8.719, Internal Timer t: 2.718, Ball Number: 2
# Time: 8.720, Internal Timer t: 2.719, Ball Number: 2
# Time: 8.721, Internal Timer t: 2.720, Ball Number: 2
# Time: 8.722, Internal Timer t: 2.721, Ball Number: 2
# Time: 8.723, Internal Timer t: 2.722, Ball Number: 2
# Time: 8.724, Internal Timer t: 2.723, Ball Number: 2
# Time: 8.725, Internal Timer t: 2.724, Ball Number: 2
# Time: 8.726, Internal Timer t: 2.725, Ball Number: 2
# Time: 8.727, Internal Timer t: 2.726, Ball Number: 2
# Time: 8.728, Internal Timer t: 2.727, Ball Number: 2
# Time: 8.729, Internal Timer t: 2.728, Ball Number: 2
# Time: 8.730, Internal Timer t: 2.729, Ball Number: 2
# Time: 8.731, Internal Timer t: 2.730, Ball Number: 2
# Time: 8.732, Internal Timer t: 2.731, Ball Number: 2
# Time: 8.733, Internal Timer t: 2.732, Ball Number: 2
# Time: 8.734, Internal Timer t: 2.733, Ball Number: 2
# Time: 8.735, Internal Timer t: 2.734, Ball Number: 2
# Time: 8.736, Internal Timer t: 2.735, Ball Number: 2
# Time: 8.737, Internal Timer t: 2.736, Ball Number: 2
# Time: 8.738, Internal Timer t: 2.737, Ball Number: 2
# Time: 8.739, Internal Timer t: 2.738, Ball Number: 2
# Time: 8.740, Internal Timer t: 2.739, Ball Number: 2
# Time: 8.741, Internal Timer t: 2.740, Ball Number: 2
# Time: 8.742, Internal Timer t: 2.741, Ball Number: 2
# Time: 8.743, Internal Timer t: 2.742, Ball Number: 2
# Time: 8.744, Internal Timer t: 2.743, Ball Number: 2
# Time: 8.745, Internal Timer t: 2.744, Ball Number: 2
# Time: 8.746, Internal Timer t: 2.745, Ball Number: 2
# Time: 8.747, Internal Timer t: 2.746, Ball Number: 2
# Time: 8.748, Internal Timer t: 2.747, Ball Number: 2
# Time: 8.749, Internal Timer t: 2.748, Ball Number: 2
# Time: 8.750, Internal Timer t: 2.749, Ball Number: 2
# Time: 8.751, Internal Timer t: 2.750, Ball Number: 2
# Time: 8.752, Internal Timer t: 2.751, Ball Number: 2
# Time: 8.753, Internal Timer t: 2.752, Ball Number: 2
# Time: 8.754, Internal Timer t: 2.753, Ball Number: 2
# Time: 8.755, Internal Timer t: 2.754, Ball Number: 2
# Time: 8.756, Internal Timer t: 2.755, Ball Number: 2
# Time: 8.757, Internal Timer t: 2.756, Ball Number: 2
# Time: 8.758, Internal Timer t: 2.757, Ball Number: 2
# Time: 8.759, Internal Timer t: 2.758, Ball Number: 2
# Time: 8.760, Internal Timer t: 2.759, Ball Number: 2
# Time: 8.761, Internal Timer t: 2.760, Ball Number: 2
# Time: 8.762, Internal Timer t: 2.761, Ball Number: 2
# Time: 8.763, Internal Timer t: 2.762, Ball Number: 2
# Time: 8.764, Internal Timer t: 2.763, Ball Number: 2
# Time: 8.765, Internal Timer t: 2.764, Ball Number: 2
# Time: 8.766, Internal Timer t: 2.765, Ball Number: 2
# Time: 8.767, Internal Timer t: 2.766, Ball Number: 2
# Time: 8.768, Internal Timer t: 2.767, Ball Number: 2
# Time: 8.769, Internal Timer t: 2.768, Ball Number: 2
# Time: 8.770, Internal Timer t: 2.769, Ball Number: 2
# Time: 8.771, Internal Timer t: 2.770, Ball Number: 2
# Time: 8.772, Internal Timer t: 2.771, Ball Number: 2
# Time: 8.773, Internal Timer t: 2.772, Ball Number: 2
# Time: 8.774, Internal Timer t: 2.773, Ball Number: 2
# Time: 8.775, Internal Timer t: 2.774, Ball Number: 2
# Time: 8.776, Internal Timer t: 2.775, Ball Number: 2
# Time: 8.777, Internal Timer t: 2.776, Ball Number: 2
# Time: 8.778, Internal Timer t: 2.777, Ball Number: 2
# Time: 8.779, Internal Timer t: 2.778, Ball Number: 2
# Time: 8.780, Internal Timer t: 2.779, Ball Number: 2
# Time: 8.781, Internal Timer t: 2.780, Ball Number: 2
# Time: 8.782, Internal Timer t: 2.781, Ball Number: 2
# Time: 8.783, Internal Timer t: 2.782, Ball Number: 2
# Time: 8.784, Internal Timer t: 2.783, Ball Number: 2
# Time: 8.785, Internal Timer t: 2.784, Ball Number: 2
# Time: 8.786, Internal Timer t: 2.785, Ball Number: 2
# Time: 8.787, Internal Timer t: 2.786, Ball Number: 2
# Time: 8.788, Internal Timer t: 2.787, Ball Number: 2
# Time: 8.789, Internal Timer t: 2.788, Ball Number: 2
# Time: 8.790, Internal Timer t: 2.789, Ball Number: 2
# Time: 8.791, Internal Timer t: 2.790, Ball Number: 2
# Time: 8.792, Internal Timer t: 2.791, Ball Number: 2
# Time: 8.793, Internal Timer t: 2.792, Ball Number: 2
# Time: 8.794, Internal Timer t: 2.793, Ball Number: 2
# Time: 8.795, Internal Timer t: 2.794, Ball Number: 2
# Time: 8.796, Internal Timer t: 2.795, Ball Number: 2
# Time: 8.797, Internal Timer t: 2.796, Ball Number: 2
# Time: 8.798, Internal Timer t: 2.797, Ball Number: 2
# Time: 8.799, Internal Timer t: 2.798, Ball Number: 2
# Time: 8.800, Internal Timer t: 2.799, Ball Number: 2
# Time: 8.801, Internal Timer t: 2.800, Ball Number: 2
# Time: 8.802, Internal Timer t: 2.801, Ball Number: 2
# Time: 8.803, Internal Timer t: 2.802, Ball Number: 2
# Time: 8.804, Internal Timer t: 2.803, Ball Number: 2
# Time: 8.805, Internal Timer t: 2.804, Ball Number: 2
# Time: 8.806, Internal Timer t: 2.805, Ball Number: 2
# Time: 8.807, Internal Timer t: 2.806, Ball Number: 2
# Time: 8.808, Internal Timer t: 2.807, Ball Number: 2
# Time: 8.809, Internal Timer t: 2.808, Ball Number: 2
# Time: 8.810, Internal Timer t: 2.809, Ball Number: 2
# Time: 8.811, Internal Timer t: 2.810, Ball Number: 2
# Time: 8.812, Internal Timer t: 2.811, Ball Number: 2
# Time: 8.813, Internal Timer t: 2.812, Ball Number: 2
# Time: 8.814, Internal Timer t: 2.813, Ball Number: 2
# Time: 8.815, Internal Timer t: 2.814, Ball Number: 2
# Time: 8.816, Internal Timer t: 2.815, Ball Number: 2
# Time: 8.817, Internal Timer t: 2.816, Ball Number: 2
# Time: 8.818, Internal Timer t: 2.817, Ball Number: 2
# Time: 8.819, Internal Timer t: 2.818, Ball Number: 2
# Time: 8.820, Internal Timer t: 2.819, Ball Number: 2
# Time: 8.821, Internal Timer t: 2.820, Ball Number: 2
# Time: 8.822, Internal Timer t: 2.821, Ball Number: 2
# Time: 8.823, Internal Timer t: 2.822, Ball Number: 2
# Time: 8.824, Internal Timer t: 2.823, Ball Number: 2
# Time: 8.825, Internal Timer t: 2.824, Ball Number: 2
# Time: 8.826, Internal Timer t: 2.825, Ball Number: 2
# Time: 8.827, Internal Timer t: 2.826, Ball Number: 2
# Time: 8.828, Internal Timer t: 2.827, Ball Number: 2
# Time: 8.829, Internal Timer t: 2.828, Ball Number: 2
# Time: 8.830, Internal Timer t: 2.829, Ball Number: 2
# Time: 8.831, Internal Timer t: 2.830, Ball Number: 2
# Time: 8.832, Internal Timer t: 2.831, Ball Number: 2
# Time: 8.833, Internal Timer t: 2.832, Ball Number: 2
# Time: 8.834, Internal Timer t: 2.833, Ball Number: 2
# Time: 8.835, Internal Timer t: 2.834, Ball Number: 2
# Time: 8.836, Internal Timer t: 2.835, Ball Number: 2
# Time: 8.837, Internal Timer t: 2.836, Ball Number: 2
# Time: 8.838, Internal Timer t: 2.837, Ball Number: 2
# Time: 8.839, Internal Timer t: 2.838, Ball Number: 2
# Time: 8.840, Internal Timer t: 2.839, Ball Number: 2
# Time: 8.841, Internal Timer t: 2.840, Ball Number: 2
# Time: 8.842, Internal Timer t: 2.841, Ball Number: 2
# Time: 8.843, Internal Timer t: 2.842, Ball Number: 2
# Time: 8.844, Internal Timer t: 2.843, Ball Number: 2
# Time: 8.845, Internal Timer t: 2.844, Ball Number: 2
# Time: 8.846, Internal Timer t: 2.845, Ball Number: 2
# Time: 8.847, Internal Timer t: 2.846, Ball Number: 2
# Time: 8.848, Internal Timer t: 2.847, Ball Number: 2
# Time: 8.849, Internal Timer t: 2.848, Ball Number: 2
# Time: 8.850, Internal Timer t: 2.849, Ball Number: 2
# Time: 8.851, Internal Timer t: 2.850, Ball Number: 2
# Time: 8.852, Internal Timer t: 2.851, Ball Number: 2
# Time: 8.853, Internal Timer t: 2.852, Ball Number: 2
# Time: 8.854, Internal Timer t: 2.853, Ball Number: 2
# Time: 8.855, Internal Timer t: 2.854, Ball Number: 2
# Time: 8.856, Internal Timer t: 2.855, Ball Number: 2
# Time: 8.857, Internal Timer t: 2.856, Ball Number: 2
# Time: 8.858, Internal Timer t: 2.857, Ball Number: 2
# Time: 8.859, Internal Timer t: 2.858, Ball Number: 2
# Time: 8.860, Internal Timer t: 2.859, Ball Number: 2
# Time: 8.861, Internal Timer t: 2.860, Ball Number: 2
# Time: 8.862, Internal Timer t: 2.861, Ball Number: 2
# Time: 8.863, Internal Timer t: 2.862, Ball Number: 2
# Time: 8.864, Internal Timer t: 2.863, Ball Number: 2
# Time: 8.865, Internal Timer t: 2.864, Ball Number: 2
# Time: 8.866, Internal Timer t: 2.865, Ball Number: 2
# Time: 8.867, Internal Timer t: 2.866, Ball Number: 2
# Time: 8.868, Internal Timer t: 2.867, Ball Number: 2
# Time: 8.869, Internal Timer t: 2.868, Ball Number: 2
# Time: 8.870, Internal Timer t: 2.869, Ball Number: 2
# Time: 8.871, Internal Timer t: 2.870, Ball Number: 2
# Time: 8.872, Internal Timer t: 2.871, Ball Number: 2
# Time: 8.873, Internal Timer t: 2.872, Ball Number: 2
# Time: 8.874, Internal Timer t: 2.873, Ball Number: 2
# Time: 8.875, Internal Timer t: 2.874, Ball Number: 2
# Time: 8.876, Internal Timer t: 2.875, Ball Number: 2
# Time: 8.877, Internal Timer t: 2.876, Ball Number: 2
# Time: 8.878, Internal Timer t: 2.877, Ball Number: 2
# Time: 8.879, Internal Timer t: 2.878, Ball Number: 2
# Time: 8.880, Internal Timer t: 2.879, Ball Number: 2
# Time: 8.881, Internal Timer t: 2.880, Ball Number: 2
# Time: 8.882, Internal Timer t: 2.881, Ball Number: 2
# Time: 8.883, Internal Timer t: 2.882, Ball Number: 2
# Time: 8.884, Internal Timer t: 2.883, Ball Number: 2
# Time: 8.885, Internal Timer t: 2.884, Ball Number: 2
# Time: 8.886, Internal Timer t: 2.885, Ball Number: 2
# Time: 8.887, Internal Timer t: 2.886, Ball Number: 2
# Time: 8.888, Internal Timer t: 2.887, Ball Number: 2
# Time: 8.889, Internal Timer t: 2.888, Ball Number: 2
# Time: 8.890, Internal Timer t: 2.889, Ball Number: 2
# Time: 8.891, Internal Timer t: 2.890, Ball Number: 2
# Time: 8.892, Internal Timer t: 2.891, Ball Number: 2
# Time: 8.893, Internal Timer t: 2.892, Ball Number: 2
# Time: 8.894, Internal Timer t: 2.893, Ball Number: 2
# Time: 8.895, Internal Timer t: 2.894, Ball Number: 2
# Time: 8.896, Internal Timer t: 2.895, Ball Number: 2
# Time: 8.897, Internal Timer t: 2.896, Ball Number: 2
# Time: 8.898, Internal Timer t: 2.897, Ball Number: 2
# Time: 8.899, Internal Timer t: 2.898, Ball Number: 2
# Time: 8.900, Internal Timer t: 2.899, Ball Number: 2
# Time: 8.901, Internal Timer t: 2.900, Ball Number: 2
# Time: 8.902, Internal Timer t: 2.901, Ball Number: 2
# Time: 8.903, Internal Timer t: 2.902, Ball Number: 2
# Time: 8.904, Internal Timer t: 2.903, Ball Number: 2
# Time: 8.905, Internal Timer t: 2.904, Ball Number: 2
# Time: 8.906, Internal Timer t: 2.905, Ball Number: 2
# Time: 8.907, Internal Timer t: 2.906, Ball Number: 2
# Time: 8.908, Internal Timer t: 2.907, Ball Number: 2
# Time: 8.909, Internal Timer t: 2.908, Ball Number: 2
# Time: 8.910, Internal Timer t: 2.909, Ball Number: 2
# Time: 8.911, Internal Timer t: 2.910, Ball Number: 2
# Time: 8.912, Internal Timer t: 2.911, Ball Number: 2
# Time: 8.913, Internal Timer t: 2.912, Ball Number: 2
# Time: 8.914, Internal Timer t: 2.913, Ball Number: 2
# Time: 8.915, Internal Timer t: 2.914, Ball Number: 2
# Time: 8.916, Internal Timer t: 2.915, Ball Number: 2
# Time: 8.917, Internal Timer t: 2.916, Ball Number: 2
# Time: 8.918, Internal Timer t: 2.917, Ball Number: 2
# Time: 8.919, Internal Timer t: 2.918, Ball Number: 2
# Time: 8.920, Internal Timer t: 2.919, Ball Number: 2
# Time: 8.921, Internal Timer t: 2.920, Ball Number: 2
# Time: 8.922, Internal Timer t: 2.921, Ball Number: 2
# Time: 8.923, Internal Timer t: 2.922, Ball Number: 2
# Time: 8.924, Internal Timer t: 2.923, Ball Number: 2
# Time: 8.925, Internal Timer t: 2.924, Ball Number: 2
# Time: 8.926, Internal Timer t: 2.925, Ball Number: 2
# Time: 8.927, Internal Timer t: 2.926, Ball Number: 2
# Time: 8.928, Internal Timer t: 2.927, Ball Number: 2
# Time: 8.929, Internal Timer t: 2.928, Ball Number: 2
# Time: 8.930, Internal Timer t: 2.929, Ball Number: 2
# Time: 8.931, Internal Timer t: 2.930, Ball Number: 2
# Time: 8.932, Internal Timer t: 2.931, Ball Number: 2
# Time: 8.933, Internal Timer t: 2.932, Ball Number: 2
# Time: 8.934, Internal Timer t: 2.933, Ball Number: 2
# Time: 8.935, Internal Timer t: 2.934, Ball Number: 2
# Time: 8.936, Internal Timer t: 2.935, Ball Number: 2
# Time: 8.937, Internal Timer t: 2.936, Ball Number: 2
# Time: 8.938, Internal Timer t: 2.937, Ball Number: 2
# Time: 8.939, Internal Timer t: 2.938, Ball Number: 2
# Time: 8.940, Internal Timer t: 2.939, Ball Number: 2
# Time: 8.941, Internal Timer t: 2.940, Ball Number: 2
# Time: 8.942, Internal Timer t: 2.941, Ball Number: 2
# Time: 8.943, Internal Timer t: 2.942, Ball Number: 2
# Time: 8.944, Internal Timer t: 2.943, Ball Number: 2
# Time: 8.945, Internal Timer t: 2.944, Ball Number: 2
# Time: 8.946, Internal Timer t: 2.945, Ball Number: 2
# Time: 8.947, Internal Timer t: 2.946, Ball Number: 2
# Time: 8.948, Internal Timer t: 2.947, Ball Number: 2
# Time: 8.949, Internal Timer t: 2.948, Ball Number: 2
# Time: 8.950, Internal Timer t: 2.949, Ball Number: 2
# Time: 8.951, Internal Timer t: 2.950, Ball Number: 2
# Time: 8.952, Internal Timer t: 2.951, Ball Number: 2
# Time: 8.953, Internal Timer t: 2.952, Ball Number: 2
# Time: 8.954, Internal Timer t: 2.953, Ball Number: 2
# Time: 8.955, Internal Timer t: 2.954, Ball Number: 2
# Time: 8.956, Internal Timer t: 2.955, Ball Number: 2
# Time: 8.957, Internal Timer t: 2.956, Ball Number: 2
# Time: 8.958, Internal Timer t: 2.957, Ball Number: 2
# Time: 8.959, Internal Timer t: 2.958, Ball Number: 2
# Time: 8.960, Internal Timer t: 2.959, Ball Number: 2
# Time: 8.961, Internal Timer t: 2.960, Ball Number: 2
# Time: 8.962, Internal Timer t: 2.961, Ball Number: 2
# Time: 8.963, Internal Timer t: 2.962, Ball Number: 2
# Time: 8.964, Internal Timer t: 2.963, Ball Number: 2
# Time: 8.965, Internal Timer t: 2.964, Ball Number: 2
# Time: 8.966, Internal Timer t: 2.965, Ball Number: 2
# Time: 8.967, Internal Timer t: 2.966, Ball Number: 2
# Time: 8.968, Internal Timer t: 2.967, Ball Number: 2
# Time: 8.969, Internal Timer t: 2.968, Ball Number: 2
# Time: 8.970, Internal Timer t: 2.969, Ball Number: 2
# Time: 8.971, Internal Timer t: 2.970, Ball Number: 2
# Time: 8.972, Internal Timer t: 2.971, Ball Number: 2
# Time: 8.973, Internal Timer t: 2.972, Ball Number: 2
# Time: 8.974, Internal Timer t: 2.973, Ball Number: 2
# Time: 8.975, Internal Timer t: 2.974, Ball Number: 2
# Time: 8.976, Internal Timer t: 2.975, Ball Number: 2
# Time: 8.977, Internal Timer t: 2.976, Ball Number: 2
# Time: 8.978, Internal Timer t: 2.977, Ball Number: 2
# Time: 8.979, Internal Timer t: 2.978, Ball Number: 2
# Time: 8.980, Internal Timer t: 2.979, Ball Number: 2
# Time: 8.981, Internal Timer t: 2.980, Ball Number: 2
# Time: 8.982, Internal Timer t: 2.981, Ball Number: 2
# Time: 8.983, Internal Timer t: 2.982, Ball Number: 2
# Time: 8.984, Internal Timer t: 2.983, Ball Number: 2
# Time: 8.985, Internal Timer t: 2.984, Ball Number: 2
# Time: 8.986, Internal Timer t: 2.985, Ball Number: 2
# Time: 8.987, Internal Timer t: 2.986, Ball Number: 2
# Time: 8.988, Internal Timer t: 2.987, Ball Number: 2
# Time: 8.989, Internal Timer t: 2.988, Ball Number: 2
# Time: 8.990, Internal Timer t: 2.989, Ball Number: 2
# Time: 8.991, Internal Timer t: 2.990, Ball Number: 2
# Time: 8.992, Internal Timer t: 2.991, Ball Number: 2
# Time: 8.993, Internal Timer t: 2.992, Ball Number: 2
# Time: 8.994, Internal Timer t: 2.993, Ball Number: 2
# Time: 8.995, Internal Timer t: 2.994, Ball Number: 2
# Time: 8.996, Internal Timer t: 2.995, Ball Number: 2
# Time: 8.997, Internal Timer t: 2.996, Ball Number: 2
# Time: 8.998, Internal Timer t: 2.997, Ball Number: 2
# Time: 8.999, Internal Timer t: 2.998, Ball Number: 2

# %%
def plot_finger_trajectory(finger_position, desired_finger_position, ball_positions):
    """
    plots the position of the finger in 2D and the position of the spatial frame {s}
    we assume that the time varying x variable is in x_pos and that the y variable is in y_pos
    """
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111)
    plt.plot(finger_position[:,0],finger_position[:,1], 'b')
    plt.plot(desired_finger_position[:,0],desired_finger_position[:,1], 'k')
    plt.xlabel('finger x position [m]')
    plt.ylabel('finger y position [m]')
    plt.xlim([-l1-l2+l0-0.05,l0+l1+l2+0.05])
    plt.ylim([-l1-l2-0.05, l1+l2+0.05])
    plt.plot([0],[0],'o',markersize=15,color='r')
    
    for ball in ball_positions:
        plt.plot([ball[0]],[ball[1]],'o',markersize=15,color='g')
        ax.annotate('Goal position', xy=(ball[0]-0.2,0.05+ball[1]), xytext=(30,0), textcoords='offset points')
    ax.annotate('Spatial frame {s}', xy=(-0.03,-0.005), xytext=(30,0), textcoords='offset points')
    
    fig = plt.figure()
    
    plt.subplot(3,1,1)
    plt.plot(time, measured_finger_position[:,0], 'b-', time, desired_finger_position[:,0], '--k')
    plt.ylabel(r'$x$')
    plt.subplot(3,1,2)
    plt.plot(time, measured_finger_position[:,1], 'b-', time, desired_finger_position[:,1], '--k')
    plt.ylabel(r'$y$')
    plt.subplot(3,1,3)
    plt.plot(time, measured_finger_position[:,2], 'b-', time, desired_finger_position[:,2], '--k')
    plt.ylabel(r'$z$')
    plt.xlabel('Time [s]')

plot_finger_trajectory(measured_finger_position, desired_finger_position, ball_positions)

# %%
def plot_joint_posvel(time, th, th_des, dth, dth_des):
    fig = plt.figure(figsize=(10,10))
    
    plt.subplot(3,2,1)
    plt.plot(time, th[:,0], 'b-', time, th_des[:,0], '--k')
    plt.ylabel(r'$\theta_0$')
    plt.subplot(3,2,3)
    plt.plot(time, th[:,1], 'b-', time, th_des[:,1], '--k')
    plt.ylabel(r'$\theta_1$')
    plt.subplot(3,2,5)
    plt.plot(time, th[:,2], 'b-', time, th_des[:,2], '--k')
    plt.ylabel(r'$\theta_2$')
    plt.xlabel('Time [s]')
    
    plt.subplot(3,2,2)
    plt.plot(time, dth[:,0], 'b-', time, dth_des[:,0], '--k')
    plt.ylabel(r'$\dot{\theta}_0$')
    plt.subplot(3,2,4)
    plt.plot(time, dth[:,1], 'b-', time, dth_des[:,1], '--k')
    plt.ylabel(r'$\dot{\theta}_1$')
    plt.subplot(3,2,6)
    plt.plot(time, dth[:,2], 'b-', time, dth_des[:,2], '--k')
    plt.ylabel(r'$\dot{\theta}_2$')
    plt.xlabel('Time [s]')
    
plot_joint_posvel(time, measured_positions, desired_positions, measured_velocities, desired_velocities)
